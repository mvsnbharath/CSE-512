# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
import copy
import random

# %% [markdown]
# ## Loading data from pkl file

# %%
with open('alice_parsed.pkl','rb') as f:
    u = pickle._Unpickler(f)
    u.encoding = 'latin1'
    data = u.load()
count, next_word_count = data[0], data[1]

# %% [markdown]
# ## Q2(b) i

# %%
def getWordProbability(word, count=count, next_word_count = next_word_count):   
    return count[word]/sum(count.values())

# Testing
getWordProbability('rabbit')
# Out:
# 0.0016590000754090944

# %%
data[1]
# Out:
# {'secondly': {'because': 2},
#  'pardon': {'said': 2, 'your': 1, 'cried': 2, 'she': 1},
#  'saves': {'a': 1},
#  'knelt': {'down': 1},
#  'four': {'feet': 1, 'thousand': 1, 'inches': 1, 'times': 3},
#  'sleep': {'twinkle': 1,
#   'these': 1,
#   'is': 1,
#   'that': 1,
#   'when': 1,
#   'youve': 1},
#  'aftertime': {'be': 1},
#  'hanging': {'down': 1, 'from': 1, 'out': 1},
#  'ringlets': {'and': 1, 'at': 1},
#  'oldest': {'rule': 1},
#  'hate': {'cats': 1},
#  'assembled': {'on': 1, 'about': 1},
#  'forget': {'to': 1, 'them': 1},
#  'whose': {'cause': 1, 'thoughts': 1},
#  'lory': {'and': 1,
#   'who': 1,
#   'alice': 1,
#   'hastily': 1,
#   'as': 1,
#   'with': 1,
#   'positively': 1},
#  'paris': {'and': 1, 'is': 1},
#  'blacking': {'i': 1},
#  'presents': {'to': 1, 'like': 1},
#  'yetits': {'rather': 1},
#  'under': {'a': 1,
#   'his': 1,
#   'her': 2,
#   'sentence': 2,
#   'it': 1,
#   'which': 1,
#   'the': 7,
#   'its': 1},
#  'inwards': {'and': 1},
#  'sorry': {'youve': 1},
#  'furrow': {'in': 1},
#  'worth': {'a': 1, 'the': 1, 'while': 1, 'hearing': 1},
#  'music': {'and': 2, 'ah': 1},
#  'rise': {'like': 1},
#  'every': {'golden': 1,
#   'door': 1,
#   'day': 1,
#   'moment': 1,
#   'way': 1,
#   'word': 1,
#   'line': 1,
#   'now': 4,
#   'christmas': 1},
#  'seals': {'turtles': 1},
#  'fireplace': {'is': 1},
#  'school': {'said': 1, 'every': 1, 'at': 1, 'in': 2},
#  'prize': {'herself': 1},
#  'wooden': {'spades': 1},
#  'pinch': {'it': 1, 'him': 1},
#  'persisted': {'how': 1, 'the': 1},
#  'drawlingthe': {'drawlingmaster': 1},
#  'screaming': {'with': 1},
#  'oblong': {'and': 1},
#  'favoured': {'by': 1},
#  'leaders': {'and': 1},
#  'farmyardwhile': {'the': 1},
#  'tired': {'and': 1, 'of': 5, 'herself': 1},
#  'feathers': {'the': 1},
#  'elegant': {'thimble': 1},
#  'likely': {'to': 2, 'story': 1, 'true': 1, 'it': 1},
#  'louder': {'tone': 1},
#  'machines': {'in': 1},
#  'shining': {'tail': 1},
#  'even': {'then': 1,
#   'room': 1,
#   'get': 1,
#   'make': 1,
#   'in': 1,
#   'when': 1,
#   'looking': 1,
#   'waiting': 1,
#   'know': 2,
#   'spoke': 1,
#   'stigand': 1,
#   'before': 1,
#   'the': 1,
#   'introduced': 1,
#   'with': 1,
#   'if': 2},
#  'meekly': {'replied': 1, 'im': 1},
#  'simplynever': {'imagine': 1},
#  'hide': {'a': 1},
#  'pace': {'said': 1},
#  'solemn': {'as': 1, 'tone': 2},
#  'thunder': {'and': 1},
#  'while': {'and': 1,
#   'all': 1,
#   'however': 1,
#   'alice': 1,
#   'till': 1,
#   'she': 6,
#   'in': 1,
#   'finding': 1,
#   'plates': 1,
#   'the': 8,
#   'finishing': 1,
#   'more': 1},
#  'poison': {'so': 1, 'or': 1, 'it': 1},
#  'above': {'a': 1, 'the': 1, 'her': 1},
#  'conduct': {'at': 1},
#  'new': {'zealand': 1, 'pair': 1, 'kind': 1, 'idea': 2},
#  'youcome': {'ill': 1},
#  'ever': {'be': 1,
#   'said': 1,
#   'getting': 1,
#   'saw': 3,
#   'since': 1,
#   'having': 2,
#   'thought': 1,
#   'to': 1,
#   'see': 2,
#   'finish': 1,
#   'so': 1,
#   'she': 1,
#   'happen': 1,
#   'heard': 1,
#   'was': 2,
#   'eat': 1,
#   'yet': 1},
#  'told': {'me': 2, 'you': 2, 'so': 1, 'her': 1},
#  'join': {'the': 9},
#  'never': {'and': 1,
#   'tasted': 1,
#   'mind': 1,
#   'one': 1,
#   'heard': 4,
#   'done': 1,
#   'go': 1,
#   'seen': 1,
#   'saw': 1,
#   'before': 1,
#   'even': 2,
#   'said': 2,
#   'learnt': 1,
#   'had': 2,
#   'been': 2,
#   'to': 1,
#   'was': 2,
#   'happened': 1,
#   'do': 2,
#   'sure': 1,
#   'get': 2,
#   'knew': 2,
#   'they': 1,
#   'come': 1,
#   'understood': 1,
#   'could': 1,
#   'thought': 1,
#   'so': 1,
#   'forgotten': 1,
#   'executes': 1,
#   'went': 1,
#   'left': 2,
#   'once': 1},
#  'wrapping': {'itself': 1},
#  'here': {'and': 5,
#   'cried': 1,
#   'one': 1,
#   'as': 1,
#   'im': 1,
#   'directly': 1,
#   'in': 1,
#   'any': 1,
#   'before': 1,
#   'said': 2,
#   'to': 1,
#   'with': 1,
#   'itll': 1,
#   'young': 1,
#   'why': 1,
#   'till': 1,
#   'digging': 1,
#   'you': 1,
#   'was': 1,
#   'ought': 1,
#   'poor': 1,
#   'run': 1,
#   'that': 2,
#   'may': 1,
#   'but': 1,
#   'come': 1,
#   'ladhere': 1,
#   'he': 1,
#   'i': 2,
#   'alice': 2,
#   'o': 1,
#   'thought': 1,
#   'she': 1,
#   'the': 7},
#  'met': {'those': 1, 'in': 2},
#  'protection': {'you': 1},
#  'hers': {'began': 1, 'would': 1, 'that': 1},
#  'cardboard': {'all': 1},
#  'shriek': {'and': 3, 'of': 2},
#  'dry': {'me': 1,
#   'again': 2,
#   'would': 1,
#   'very': 1,
#   'leaves': 1,
#   'enough': 1,
#   'he': 1},
#  'daughter': {'ah': 1},
#  'sobs': {'to': 1, 'choked': 1, 'lastly': 1, 'of': 1},
#  'leaves': {'and': 1, 'i': 1, 'as': 1, 'which': 1, 'that': 2},
#  'changed': {'do': 1,
#   'his': 1,
#   'for': 2,
#   'into': 1,
#   'since': 1,
#   'in': 1,
#   'several': 1},
#  'swam': {'nearer': 1, 'about': 1, 'slowly': 1, 'lazily': 1, 'to': 1},
#  'barrowful': {'will': 1, 'of': 1},
#  'waterwell': {'said': 1},
#  'smoke': {'from': 1},
#  'pack': {'of': 3, 'she': 1, 'rose': 1},
#  'changes': {'she': 1, 'are': 1},
#  'ventured': {'to': 4},
#  'golden': {'scale': 1, 'key': 6},
#  'sourand': {'camomile': 1},
#  'ground': {'near': 1, 'so': 1, 'alice': 1, 'as': 1},
#  'explained': {'said': 1},
#  'angrily': {'a': 1,
#   'away': 1,
#   'it': 1,
#   'but': 1,
#   'rearing': 1,
#   'here': 1,
#   'really': 1,
#   'or': 1,
#   'at': 1},
#  'feelings': {'i': 1, 'may': 1},
#  'brought': {'them': 1, 'herself': 1, 'it': 1},
#  'patience': {'of': 1},
#  'moral': {'and': 1, 'of': 6, 'if': 1},
#  'guests': {'to': 1, 'had': 1, 'mostly': 1},
#  'drowned': {'in': 1},
#  'punching': {'him': 1},
#  'spoke': {'and': 3,
#   'a': 1,
#   'we': 1,
#   'unimportant': 1,
#   'for': 1,
#   'i': 1,
#   'it': 1,
#   'but': 1,
#   'alice': 1,
#   'to': 1,
#   'as': 1,
#   'at': 1,
#   'the': 1,
#   'either': 1},
#  'would': {'all': 2,
#   'feel': 2,
#   'manage': 1,
#   'it': 1,
#   'twist': 1,
#   'put': 1,
#   'cost': 1,
#   'bend': 1,
#   'have': 5,
#   'in': 1,
#   'go': 5,
#   'happen': 3,
#   'seem': 1,
#   'said': 1,
#   'not': 12,
#   'make': 1,
#   'only': 1,
#   'call': 1,
#   'take': 1,
#   'you': 6,
#   'hardly': 1,
#   'be': 17,
#   'get': 1,
#   'break': 1,
#   'catch': 1,
#   'change': 3,
#   'deny': 1,
#   'like': 1,
#   'always': 1,
#   'ever': 1,
#   'gather': 1,
#   'keep': 1,
#   'die': 1,
#   'become': 2,
#   'the': 1,
#   'talk': 1},
#  'arms': {'and': 2, 'folded': 2, 'took': 1, 'round': 1},
#  'insult': {'me': 1},
#  'dormouses': {'place': 1},
#  'call': {'the': 3, 'after': 1, 'it': 3, 'him': 2},
#  'therefore': {'im': 1},
#  'leant': {'against': 1},
#  'fainting': {'in': 1},
#  'tell': {'me': 8,
#   'them': 1,
#   'him': 1,
#   'her': 3,
#   'himit': 1,
#   'what': 1,
#   'us': 2,
#   'it': 1,
#   'whether': 1,
#   'you': 10,
#   'youall': 1,
#   'its': 1},
#  'breathe': {'i': 1, 'when': 1, 'it': 1},
#  'peeping': {'anxiously': 1},
#  'evening': {'beautiful': 2},
#  'hurt': {'and': 1, 'the': 1, 'it': 1},
#  'grief': {'they': 1},
#  'glass': {'and': 1,
#   'box': 1,
#   'what': 1,
#   'from': 1,
#   'there': 1,
#   'table': 3,
#   'now': 1},
#  'excellent': {'opportunity': 1, 'plan': 1},
#  'adjourn': {'for': 1},
#  'hold': {'of': 4, 'it': 2, 'your': 3},
#  'must': {'be': 19,
#   'needs': 1,
#   'manage': 1,
#   'remember': 1,
#   'crossexamine': 2,
#   'i': 1,
#   'make': 1,
#   'burn': 1,
#   'sugar': 1,
#   'know': 1,
#   'have': 10,
#   'go': 3,
#   'the': 1,
#   'ever': 1},
#  'me': {'and': 1,
#   'executed': 1,
#   'help': 1,
#   'please': 1,
#   'seehow': 1,
#   'see': 3,
#   'smaller': 1,
#   'at': 2,
#   'beautifully': 1,
#   'next': 1,
#   'your': 1,
#   'out': 2,
#   'giddy': 1,
#   'said': 5,
#   'pat': 1,
#   'for': 3,
#   'there': 2,
#   'when': 1,
#   'grow': 3,
#   'to': 3,
#   'too': 1,
#   'you': 2,
#   'that': 2,
#   'very': 1,
#   'who': 1,
#   'but': 2,
#   'luckily': 1,
#   'hear': 1,
#   'alone': 1,
#   'by': 1,
#   'he': 1,
#   'a': 2,
#   'on': 1,
#   'like': 3,
#   'whether': 1,
#   'ill': 1,
#   'larger': 1,
#   'well': 1,
#   'theyre': 1,
#   'thought': 1,
#   'were': 1,
#   'the': 2,
#   'thats': 1,
#   'my': 1,
#   'think': 1,
#   'left': 1},
#  'locked': {'and': 1},
#  'room': {'again': 1,
#   'said': 1,
#   'for': 3,
#   'no': 1,
#   'when': 1,
#   'to': 2,
#   'at': 1,
#   'they': 1,
#   'the': 1,
#   'with': 1},
#  'work': {'and': 1,
#   'very': 2,
#   'it': 1,
#   'throwing': 1,
#   'at': 1,
#   'nibbling': 1,
#   'shaking': 1},
#  'dodo': {'a': 1,
#   'replied': 1,
#   'solemnly': 2,
#   'managed': 1,
#   'pointing': 1,
#   'then': 1,
#   'suddenly': 1,
#   'could': 1,
#   'had': 1,
#   'said': 1,
#   'in': 1,
#   'the': 1},
#  'worm': {'the': 1},
#  'roof': {'of': 2, 'there': 1, 'off': 1, 'bearmind': 1, 'was': 1},
#  'obstacle': {'that': 1},
#  'isbirds': {'of': 1},
#  'elbow': {'on': 1, 'was': 1, 'against': 1},
#  'my': {'own': 2,
#   'tea': 2,
#   'mind': 1,
#   'shoulders': 2,
#   'teanot': 1,
#   'hair': 1,
#   'dear': 11,
#   'right': 2,
#   'throat': 1,
#   'arm': 1,
#   'size': 1,
#   'dears': 1,
#   'heads': 1,
#   'jaw': 1,
#   'adventuresbeginning': 1,
#   'forehead': 1,
#   'tail': 2,
#   'going': 1,
#   'way': 1,
#   'poor': 2,
#   'head': 1,
#   'limbs': 1,
#   'hand': 1,
#   'plan': 1,
#   'kitchen': 1,
#   'boy': 1,
#   'fur': 1,
#   'name': 1,
#   'wife': 1,
#   'life': 4,
#   'youth': 3,
#   'gloves': 1,
#   'time': 1,
#   'elbow': 1,
#   'ears': 1,
#   'notion': 1,
#   'history': 1},
#  'shook': {'both': 1, 'the': 1, 'his': 3, 'itself': 2, 'its': 2},
#  'rosetree': {'and': 1, 'stood': 1, 'she': 1, 'for': 1},
#  'quiver': {'all': 1},
#  'serpent': {'and': 1,
#   'said': 1,
#   'i': 2,
#   'it': 1,
#   'but': 1,
#   'screamed': 1,
#   'she': 1,
#   'thats': 1},
#  'give': {'them': 1,
#   'your': 3,
#   'all': 1,
#   'it': 1,
#   'him': 1,
#   'yourself': 1,
#   'birthday': 1,
#   'you': 1,
#   'the': 2},
#  'unjust': {'things': 1},
#  'flung': {'down': 1},
#  'frighten': {'them': 1},
#  'want': {'a': 1, 'to': 6, 'you': 1, 'yours': 1},
#  'extraordinary': {'ways': 1, 'noise': 1},
#  'keep': {'them': 1,
#   'appearing': 1,
#   'it': 1,
#   'back': 2,
#   'tight': 1,
#   'moving': 1,
#   'through': 1,
#   'the': 1,
#   'herself': 1,
#   'your': 1},
#  'returned': {'from': 2},
#  'end': {'then': 1, 'said': 1, 'i': 1, 'of': 11, 'to': 1, 'you': 1, 'if': 1},
#  'turn': {'and': 1,
#   'a': 1,
#   'them': 2,
#   'that': 1,
#   'into': 2,
#   'or': 1,
#   'not': 1,
#   'round': 1},
#  'complaining': {'tone': 1},
#  'agony': {'of': 1},
#  'returning': {'splendidly': 1},
#  'how': {'this': 1,
#   'brave': 1,
#   'old': 1,
#   'eagerly': 1,
#   'is': 1,
#   'in': 1,
#   'am': 2,
#   'it': 1,
#   'are': 2,
#   'queer': 2,
#   'odd': 1,
#   'cheerfully': 1,
#   'funny': 2,
#   'puzzling': 2,
#   'long': 1,
#   'should': 1,
#   'late': 1,
#   'to': 5,
#   'dreadfully': 1,
#   'confusing': 1,
#   'surprised': 1,
#   'she': 6,
#   'do': 3,
#   'fond': 1,
#   'far': 1,
#   'neatly': 1,
#   'doth': 3,
#   'glad': 1,
#   'he': 2,
#   'i': 2,
#   'many': 2,
#   'could': 1,
#   'large': 1,
#   'did': 2,
#   'delightful': 1,
#   'can': 2,
#   'small': 1,
#   'the': 4},
#  'hot': {'tea': 1, 'buttered': 1, 'tureen': 1, 'day': 1, 'she': 1},
#  'piecrust': {'and': 1},
#  'answer': {'i': 1,
#   'questionshow': 1,
#   'theyre': 1,
#   'to': 2,
#   'without': 1,
#   'so': 2,
#   'either': 1},
#  'arminarm': {'with': 1},
#  'truthful': {'child': 1},
#  'poker': {'will': 1},
#  'flustered': {'to': 1},
#  'mouths': {'and': 1, 'so': 2},
#  'after': {'a': 9,
#   'these': 1,
#   'all': 6,
#   'folding': 1,
#   'hunting': 1,
#   'her': 3,
#   'that': 3,
#   'this': 1,
#   'watching': 1,
#   'some': 1,
#   'it': 5,
#   'thinking': 1,
#   'waiting': 1,
#   'them': 1,
#   'thatonly': 1,
#   'such': 1,
#   'the': 4,
#   'glaring': 1},
#  'wrong': {'sighed': 1, 'from': 1, 'about': 1, 'im': 1, 'and': 1},
#  'jumping': {'merrily': 1, 'about': 1, 'up': 2},
#  'lay': {'far': 1, 'on': 1, 'the': 1, 'sprawling': 1},
#  'curiosity': {'and': 1, 'what': 1, 'soles': 1, 'she': 1, 'its': 1},
#  'law': {'i': 1, 'and': 1},
#  'lap': {'of': 1, 'as': 1},
#  'attempt': {'proved': 1},
#  'soooop': {'beauootiful': 2, 'of': 3, 'soooop': 2},
#  'childhood': {'and': 1},
#  'wink': {'of': 1, 'with': 1},
#  'wriggling': {'down': 1},
#  'green': {'leaves': 2, 'stuff': 1, 'waiting': 1},
#  'goodbye': {'feet': 1},
#  'aloud': {'i': 2, 'and': 1, 'addressing': 1, 'do': 1},
#  'order': {'of': 1, 'continued': 1, 'one': 1},
#  'wind': {'and': 2},
#  'wine': {'the': 1, 'she': 1},
#  'withina': {'constant': 1},
#  'executed': {'on': 1, 'all': 1, 'for': 1, 'whether': 1, 'as': 1, 'the': 1},
#  'dreamed': {'of': 1},
#  'over': {'and': 4,
#   'me': 1,
#   'all': 2,
#   'his': 2,
#   'afterwards': 1,
#   'her': 1,
#   'to': 3,
#   'its': 1,
#   'crumbs': 1,
#   'alice': 2,
#   'here': 1,
#   'however': 1,
#   'thought': 1,
#   'their': 3,
#   'other': 1,
#   'at': 2,
#   'a': 1,
#   'heels': 1,
#   'yes': 1,
#   'with': 3,
#   'the': 7},
#  'london': {'is': 1},
#  'mabel': {'ill': 2, 'after': 1, 'for': 1},
#  'before': {'and': 5,
#   'them': 1,
#   'said': 2,
#   'her': 1,
#   'that': 1,
#   'i': 1,
#   'never': 1,
#   'alice': 1,
#   'but': 2,
#   'oh': 1,
#   'as': 1,
#   'sure': 1,
#   'she': 9,
#   'they': 1,
#   'seen': 1,
#   'the': 4,
#   'if': 1,
#   'its': 2,
#   'he': 1},
#  'thenbills': {'to': 1},
#  'chatte': {'which': 1},
#  'fit': {'you': 2, 'an': 1},
#  'somewhere': {'down': 1, 'near': 1, 'alice': 1},
#  'lefthand': {'bit': 2},
#  'fix': {'on': 1},
#  'writing': {'very': 1, 'down': 1, 'on': 1, 'in': 1},
#  'better': {'and': 1,
#   'finish': 1,
#   'this': 1,
#   'ask': 1,
#   'alice': 1,
#   'leave': 1,
#   'to': 1,
#   'nowbut': 1,
#   'take': 1,
#   'not': 2,
#   'now': 1,
#   'with': 1,
#   'id': 1},
#  'fig': {'said': 1},
#  'glanced': {'rather': 1},
#  'croquet': {'then': 1, 'the': 2, 'with': 2, 'she': 1},
#  'weeks': {'im': 1},
#  'overcome': {'to': 1},
#  'then': {'and': 2,
#   'saying': 1,
#   'all': 1,
#   'followed': 2,
#   'turned': 1,
#   'it': 6,
#   'hurried': 1,
#   'raised': 1,
#   'im': 1,
#   'at': 1,
#   'another': 1,
#   'keep': 1,
#   'if': 1,
#   'what': 1,
#   'said': 5,
#   'dipped': 1,
#   'her': 1,
#   'explain': 1,
#   'when': 1,
#   'treading': 1,
#   'you': 5,
#   'sat': 1,
#   'tell': 1,
#   'roared': 1,
#   'we': 1,
#   'added': 1,
#   'turning': 1,
#   'unrolled': 1,
#   'after': 1,
#   'stop': 1,
#   'they': 4,
#   'such': 1,
#   'nodded': 1,
#   'he': 1,
#   'a': 3,
#   'againbefore': 1,
#   'quietly': 1,
#   'i': 1,
#   'came': 1,
#   'ill': 2,
#   'alice': 3,
#   'theyre': 1,
#   'thought': 2,
#   'turn': 1,
#   'drawlingthe': 1,
#   'she': 8,
#   'the': 11,
#   'yours': 1,
#   'silence': 1},
#  'them': {'and': 9,
#   'all': 2,
#   'sourand': 1,
#   'over': 1,
#   'back': 1,
#   'up': 2,
#   'screamed': 1,
#   'raw': 1,
#   'as': 2,
#   'im': 1,
#   'something': 1,
#   'in': 3,
#   'best': 1,
#   'out': 3,
#   'even': 1,
#   'again': 1,
#   'what': 1,
#   'said': 1,
#   'her': 1,
#   'their': 1,
#   'when': 2,
#   'off': 1,
#   'fast': 1,
#   'to': 2,
#   'before': 1,
#   'into': 1,
#   'red': 1,
#   'can': 1,
#   'bowed': 1,
#   'hit': 1,
#   'attempted': 1,
#   'after': 1,
#   'however': 1,
#   'but': 1,
#   'quite': 1,
#   'didnt': 1,
#   'free': 1,
#   'they': 2,
#   'such': 1,
#   'with': 4,
#   'a': 2,
#   'about': 1,
#   'word': 1,
#   'i': 2,
#   'of': 1,
#   'alice': 2,
#   'called': 1,
#   'thought': 1,
#   'this': 1,
#   'so': 2,
#   'she': 1,
#   'were': 1,
#   'the': 2,
#   'bitterandand': 1,
#   'round': 1,
#   'say': 1,
#   'at': 2},
#  'romeno': {'thats': 1},
#  'slate': {'herald': 1, 'with': 1},
#  'safe': {'to': 1, 'in': 1},
#  'break': {'the': 1, 'she': 1},
#  'caterpillar': {'chapter': 1,
#   'and': 3,
#   'just': 1,
#   'decidedly': 1,
#   'that': 1,
#   'this': 1,
#   'is': 1,
#   'well': 4,
#   'took': 2,
#   'here': 1,
#   'alice': 3,
#   'sternly': 1,
#   'im': 1,
#   'angrily': 1,
#   'not': 1,
#   'contemptuously': 1,
#   'the': 1,
#   'was': 1,
#   'called': 1,
#   'seemed': 1},
#  'they': {'all': 13,
#   'set': 1,
#   'play': 1,
#   'cried': 1,
#   'doing': 1,
#   'liked': 2,
#   'hurried': 1,
#   'cant': 2,
#   'lived': 2,
#   'are': 3,
#   'have': 2,
#   'in': 1,
#   'seem': 1,
#   'saw': 3,
#   'couldnt': 3,
#   'sat': 2,
#   'looked': 1,
#   'said': 1,
#   'slipped': 1,
#   'would': 6,
#   'began': 3,
#   'had': 9,
#   'should': 1,
#   'live': 3,
#   'dont': 2,
#   'take': 1,
#   'passed': 1,
#   'got': 3,
#   'seemed': 1,
#   'told': 1,
#   'pinched': 1,
#   'do': 1,
#   'draw': 2,
#   'used': 2,
#   'hit': 1,
#   'very': 1,
#   'never': 1,
#   'drew': 1,
#   'met': 1,
#   'repeated': 1,
#   'arrived': 1,
#   'lay': 2,
#   'havent': 1,
#   'must': 3,
#   'wont': 1,
#   'both': 3,
#   'made': 1,
#   'wouldnt': 1,
#   'could': 2,
#   'lessen': 1,
#   'walked': 2,
#   'will': 1,
#   'were': 18,
#   'went': 2,
#   'gave': 2,
#   'came': 1},
#  'interrupt': {'again': 1},
#  'one': {'and': 1,
#   'flapper': 1,
#   'crazy': 1,
#   'old': 1,
#   'they': 2,
#   'wasnt': 1,
#   'indeed': 1,
#   'in': 1,
#   'one': 1,
#   'respectable': 1,
#   'as': 1,
#   'doesnt': 1,
#   'corner': 1,
#   'cant': 1,
#   'sharp': 1,
#   'arm': 1,
#   'quite': 1,
#   'said': 3,
#   'eye': 3,
#   'for': 2,
#   'paw': 1,
#   'there': 1,
#   'two': 1,
#   'to': 1,
#   'only': 1,
#   'finger': 4,
#   'way': 2,
#   'place': 1,
#   'who': 2,
#   'that': 1,
#   'time': 1,
#   'but': 2,
#   'hand': 3,
#   'knee': 2,
#   'listening': 1,
#   'foot': 3,
#   'end': 2,
#   'else': 1,
#   'with': 1,
#   'minute': 1,
#   'on': 1,
#   'about': 1,
#   'repeat': 1,
#   'would': 1,
#   'of': 22,
#   'could': 1,
#   'eats': 1,
#   'or': 1,
#   'waynever': 1,
#   'so': 1,
#   'apiece': 1,
#   'elbow': 1,
#   'the': 1,
#   'bills': 1,
#   'side': 5,
#   'alice': 2,
#   'left': 1},
#  'bank': {'and': 1, 'with': 1},
#  'pegs': {'she': 1},
#  'theni': {'shouldnt': 1},
#  'grammar': {'a': 1},
#  'meat': {'while': 1},
#  'alternately': {'without': 1},
#  'herald': {'read': 1},
#  'eleventh': {'day': 1},
#  'roast': {'turkey': 1},
#  'each': {'case': 1, 'hand': 1, 'other': 2, 'time': 1, 'with': 1, 'side': 2},
#  'went': {'back': 4,
#   'alice': 2,
#   'down': 2,
#   'as': 1,
#   'in': 3,
#   'out': 1,
#   'nearer': 1,
#   'hunting': 1,
#   'to': 7,
#   'slowly': 1,
#   'stamping': 1,
#   'timidly': 1,
#   'mad': 1,
#   'one': 1,
#   'by': 1,
#   'on': 48,
#   'off': 1,
#   'straight': 1,
#   'up': 1,
#   'sh': 1,
#   'so': 1,
#   'round': 1,
#   'once': 1},
#  'side': {'and': 3, 'of': 6, 'will': 2, 'to': 2, 'as': 1, 'she': 1, 'the': 2},
#  'cornerno': {'tie': 1},
#  'mean': {'what': 3,
#   'said': 1,
#   'that': 1,
#   'it': 1,
#   'you': 1,
#   'purpose': 1,
#   'the': 1,
#   'by': 1},
#  'calmly': {'though': 1},
#  'telescope': {'i': 1, 'and': 1, 'that': 1},
#  'series': {'of': 1},
#  'dodged': {'behind': 1},
#  'vote': {'the': 1},
#  'taught': {'them': 1, 'laughing': 1, 'us': 2},
#  'forgot': {'how': 1, 'you': 1},
#  'flock': {'together': 1},
#  'ring': {'and': 1, 'with': 1},
#  'reminding': {'her': 1},
#  'velvet': {'cushion': 1},
#  'eeevening': {'beautiful': 3},
#  'sighing': {'as': 1, 'it': 1, 'in': 1},
#  'fellows': {'were': 1},
#  'content': {'now': 1},
#  'laid': {'his': 1, 'for': 1},
#  'millennium': {'fulcrum': 1},
#  'got': {'into': 3,
#   'back': 2,
#   'down': 1,
#   'in': 2,
#   'its': 2,
#   'no': 2,
#   'any': 1,
#   'their': 1,
#   'behind': 2,
#   'much': 1,
#   'thrown': 1,
#   'used': 1,
#   'altered': 1,
#   'to': 10,
#   'it': 1,
#   'entangled': 1,
#   'burnt': 1,
#   'a': 1,
#   'up': 7,
#   'so': 2,
#   'the': 1,
#   'settled': 1},
#  'size': {'and': 1,
#   'do': 1,
#   'for': 2,
#   'again': 1,
#   'that': 1,
#   'alice': 1,
#   'by': 1,
#   'to': 2,
#   'the': 1,
#   'why': 2},
#  'splashed': {'his': 1},
#  'fondofof': {'dogs': 1},
#  'turning': {'purple': 1, 'to': 10, 'into': 1},
#  'speakand': {'they': 1},
#  'lessonbook': {'the': 1},
#  'given': {'by': 1},
#  'free': {'of': 1, 'exactly': 1, 'at': 1},
#  'uglification': {'and': 1, 'alice': 1},
#  'thatit': {'was': 1},
#  'whereupon': {'the': 1},
#  'mallets': {'live': 1},
#  'wanted': {'to': 1, 'much': 1, 'leaders': 1, 'it': 1},
#  'telescopes': {'this': 1},
#  'enormous': {'puppy': 1},
#  'ate': {'a': 1},
#  'shelves': {'as': 1},
#  'writhing': {'of': 1},
#  'cackled': {'out': 1},
#  'messages': {'for': 1, 'next': 1},
#  'days': {'and': 1, 'wrong': 1, 'the': 1, 'but': 1},
#  'pence': {'take': 1},
#  'hopeless': {'than': 1},
#  'arrived': {'with': 1},
#  'footsteps': {'and': 1, 'in': 1},
#  'bite': {'and': 1, 'alice': 1},
#  'enjoy': {'the': 1},
#  'voicethe': {'rabbitspat': 1},
#  'dunce': {'go': 1},
#  'curiouser': {'and': 1, 'cried': 1},
#  'encouraging': {'tone': 1, 'opening': 1},
#  'hearing': {'this': 1, 'her': 1, 'for': 1, 'anything': 1},
#  'wash': {'the': 1, 'off': 1},
#  'another': {'rush': 1,
#   'puzzling': 1,
#   'figure': 1,
#   'confusion': 1,
#   'dig': 1,
#   'question': 1,
#   'however': 1,
#   'long': 1,
#   'snatch': 1,
#   'shore': 1,
#   'moment': 5,
#   'of': 1,
#   'dead': 1,
#   'key': 1,
#   'footman': 1,
#   'minute': 2,
#   'hedgehog': 1},
#  'thoughtfully': {'i': 1, 'they': 1, 'at': 1, 'but': 1},
#  'thick': {'wood': 1},
#  'awfully': {'clever': 1},
#  'xii': {'alices': 2},
#  'top': {'of': 7, 'with': 1},
#  'girls': {'of': 1, 'eat': 1, 'in': 1},
#  'airs': {'do': 1},
#  'master': {'was': 1, 'says': 1, 'though': 1},
#  'too': {'large': 1,
#   'said': 1,
#   'flustered': 1,
#   'brown': 1,
#   'stiff': 1,
#   'far': 3,
#   'began': 1,
#   'that': 1,
#   'weak': 1,
#   'long': 1,
#   'dark': 1,
#   'bad': 1,
#   'much': 5,
#   'slippery': 1,
#   'but': 1,
#   'late': 1,
#   'small': 1,
#   'close': 1,
#   'yes': 1,
#   'glad': 1},
#  'wildly': {'about': 1, 'up': 1},
#  'legs': {'of': 1, 'hanging': 1, 'in': 1},
#  'dogs': {'not': 1, 'the': 1, 'either': 1, 'it': 1},
#  'listen': {'to': 3, 'all': 1, 'mary': 1, 'the': 2},
#  'consented': {'to': 1},
#  'ceiling': {'and': 1},
#  'solemnly': {'dancing': 1, 'rising': 1, 'alice': 1, 'presented': 1},
#  'took': {'a': 3,
#   'me': 1,
#   'them': 1,
#   'her': 1,
#   'no': 1,
#   'up': 3,
#   'down': 1,
#   'to': 1,
#   'courage': 1,
#   'piecrust': 1,
#   'the': 10},
#  'hadnt': {'gone': 1,
#   'cried': 1,
#   'drunk': 1,
#   'quite': 1,
#   'to': 1,
#   'begun': 1,
#   'time': 1,
#   'mentioned': 1},
#  'positively': {'refused': 1},
#  'character': {'but': 1},
#  'begins': {'i': 1, 'with': 3},
#  'distance': {'and': 3, 'come': 1, 'screaming': 1, 'would': 1, 'sitting': 1},
#  'withoutmaybe': {'its': 1},
#  'coward': {'and': 1},
#  'tree': {'a': 1, 'did': 1, 'by': 1, 'in': 2},
#  'second': {'thing': 1, 'verse': 1, 'thoughts': 1, 'time': 1},
#  'seated': {'on': 1},
#  'shower': {'of': 2},
#  'matter': {'a': 1,
#   'on': 1,
#   'worse': 1,
#   'it': 1,
#   'to': 1,
#   'much': 1,
#   'which': 2,
#   'with': 1},
#  'splendidly': {'dressed': 1},
#  'exclaimed': {'you': 1, 'turning': 1, 'alice': 3, 'in': 1},
#  'flame': {'of': 1},
#  'williams': {'conduct': 1},
#  'askance': {'said': 1},
#  'feeling': {'a': 1, 'very': 3, 'said': 1, 'at': 1, 'quite': 1},
#  'humble': {'tone': 1},
#  'ran': {'off': 3,
#   'to': 1,
#   'till': 1,
#   'away': 1,
#   'but': 1,
#   'round': 1,
#   'how': 1,
#   'as': 1,
#   'wildly': 1,
#   'close': 1,
#   'the': 1,
#   'with': 1,
#   'across': 1,
#   'out': 1},
#  'faceand': {'she': 1},
#  'shyly': {'ii': 1},
#  'modern': {'with': 1},
#  'mind': {'and': 1,
#   'about': 1,
#   'said': 2,
#   'that': 1,
#   'what': 1,
#   'as': 1,
#   'she': 1,
#   'the': 1,
#   'now': 1},
#  'mine': {'said': 2, 'is': 1, 'doesnt': 1, 'coming': 1, 'the': 2, 'before': 1},
#  'sorrow': {'you': 1, 'she': 1},
#  'talking': {'again': 1,
#   'about': 1,
#   'just': 1,
#   'to': 3,
#   'of': 1,
#   'over': 1,
#   'alice': 1,
#   'together': 1,
#   'how': 1,
#   'at': 1,
#   'in': 2,
#   'dear': 1,
#   'such': 1,
#   'familiarly': 1},
#  'manner': {'of': 1, 'smiling': 1},
#  'seen': {'a': 3,
#   'them': 3,
#   'that': 1,
#   'hatters': 1,
#   'when': 1,
#   'she': 1,
#   'in': 1,
#   'such': 2,
#   'the': 1},
#  'seem': {'to': 7, 'sending': 1},
#  'tells': {'the': 1, 'us': 1},
#  'contents': {'chapter': 1},
#  'eels': {'of': 1},
#  'strength': {'which': 1},
#  'mostly': {'kings': 1, 'said': 1},
#  'thoroughly': {'enjoy': 1, 'puzzled': 1},
#  'doori': {'do': 1},
#  'eagerly': {'and': 1,
#   'for': 1,
#   'that': 1,
#   'there': 1,
#   'half': 1,
#   'the': 1,
#   'wrote': 1,
#   'thats': 1},
#  'subjects': {'on': 1},
#  'guineapig': {'head': 1, 'cheered': 1},
#  'doors': {'of': 1, 'all': 1},
#  'laughed': {'let': 1, 'so': 1},
#  'creatures': {'wouldnt': 1,
#   'of': 1,
#   'who': 1,
#   'alice': 1,
#   'hid': 1,
#   'she': 1,
#   'got': 1,
#   'you': 1,
#   'argue': 1,
#   'order': 1},
#  'gravy': {'and': 1},
#  'nobody': {'spoke': 1,
#   'moved': 1,
#   'seems': 1,
#   'attends': 1,
#   'which': 1,
#   'in': 1,
#   'you': 1,
#   'asked': 1},
#  'though': {'this': 1,
#   'i': 1,
#   'as': 1,
#   'she': 4,
#   'they': 1,
#   'you': 1,
#   'still': 1,
#   'he': 1},
#  'regular': {'course': 1, 'rule': 1},
#  'mouth': {'and': 4,
#   'again': 1,
#   'open': 1,
#   'but': 1,
#   'enough': 1,
#   'close': 1,
#   'with': 1},
#  'plenty': {'of': 2},
#  'grave': {'and': 1, 'voice': 1, 'that': 1},
#  'zealand': {'or': 1},
#  'alarm': {'this': 1, 'in': 1},
#  'm': {'such': 1, 'said': 1, 'why': 1, 'but': 1},
#  'dog': {'growls': 1, 'near': 1},
#  'ridiculous': {'fashion': 1},
#  'pineapple': {'roast': 1},
#  'notion': {'how': 2, 'was': 1},
#  'came': {'ten': 1,
#   'suddenly': 1,
#   'into': 2,
#   'back': 1,
#   'an': 1,
#   'skimming': 1,
#   'in': 2,
#   'trotting': 1,
#   'nearer': 1,
#   'different': 2,
#   'rather': 1,
#   'flying': 1,
#   'to': 2,
#   'between': 1,
#   'opposite': 1,
#   'very': 1,
#   'upon': 5,
#   'running': 1,
#   'jumping': 1,
#   'rattling': 1,
#   'a': 3,
#   'carried': 1,
#   'oh': 1,
#   'up': 2,
#   'near': 1,
#   'the': 3,
#   'first': 1},
#  'decidedly': {'and': 3, 'uncivil': 1},
#  'saying': {'lessons': 1,
#   'and': 1,
#   'we': 1,
#   'thank': 1,
#   'anything': 1,
#   'to': 7,
#   'in': 1,
#   'come': 1,
#   'tell': 1},
#  'currants': {'well': 1},
#  'pardoned': {'come': 1},
#  'steamengine': {'when': 1},
#  'pope': {'was': 1},
#  'lewis': {'carroll': 1},
#  'queen': {'and': 7,
#   'pointing': 1,
#   'sentence': 1,
#   'had': 3,
#   'merely': 1,
#   'turned': 2,
#   'it': 1,
#   'an': 1,
#   'till': 1,
#   'say': 1,
#   'added': 1,
#   'in': 3,
#   'really': 1,
#   'said': 5,
#   'to': 1,
#   'ordering': 1,
#   'jumped': 1,
#   'tossing': 1,
#   'furiously': 1,
#   'their': 1,
#   'you': 1,
#   'was': 4,
#   'today': 1,
#   'stamping': 1,
#   'turning': 1,
#   'who': 4,
#   'but': 1,
#   'smiled': 1,
#   'put': 1,
#   'never': 2,
#   'shouted': 1,
#   'i': 2,
#   'of': 4,
#   'well': 1,
#   'shrieked': 1,
#   'will': 1,
#   'so': 1,
#   'can': 1,
#   'the': 2,
#   'left': 1,
#   'first': 1},
#  'sage': {'as': 1},
#  'ending': {'with': 1},
#  'attempts': {'at': 1},
#  'queer': {'wont': 1,
#   'little': 1,
#   'to': 1,
#   'things': 1,
#   'noises': 1,
#   'it': 1,
#   'everything': 1,
#   'indeed': 1,
#   'thing': 1,
#   'today': 1},
#  'earth': {'how': 1, 'let': 1, 'takes': 1, 'at': 1},
#  'toast': {'she': 1},
#  'busy': {'farmyardwhile': 1, 'bee': 1},
#  'spite': {'of': 1},
#  'explain': {'myself': 1, 'all': 1, 'it': 4, 'yourself': 1, 'to': 1, 'the': 2},
#  'folded': {'frowning': 1, 'quietly': 1, 'her': 1},
#  'sugar': {'my': 1},
#  'itsits': {'a': 1},
#  'deepest': {'contempt': 1},
#  'disgust': {'and': 1},
#  'themi': {'wish': 1},
#  'do': {'and': 2,
#   'almost': 1,
#   'it': 4,
#   'as': 1,
#   'bats': 1,
#   'something': 1,
#   'wonder': 1,
#   'lessons': 1,
#   'said': 5,
#   'how': 1,
#   'with': 2,
#   'next': 3,
#   'to': 4,
#   'cats': 3,
#   'you': 17,
#   'hope': 1,
#   'that': 3,
#   'very': 1,
#   'but': 1,
#   'let': 1,
#   'nothing': 1,
#   'such': 1,
#   'pleaded': 1,
#   'come': 1,
#   'why': 1,
#   'a': 1,
#   'anything': 1,
#   'i': 2,
#   'wish': 2,
#   'itthat': 1,
#   'no': 1,
#   'well': 1,
#   'alice': 2,
#   'this': 1,
#   'without': 1,
#   'so': 3,
#   'either': 1,
#   'ill': 2,
#   'lying': 1,
#   'once': 1},
#  'cartwheels': {'and': 1},
#  'squeaking': {'of': 1, 'voice': 1},
#  'stop': {'and': 1, 'these': 1, 'this': 1, 'well': 1, 'to': 1, 'in': 1},
#  'coast': {'you': 1},
#  'pocket': {'and': 2, 'till': 1, 'the': 1, 'he': 1},
#  'shutting': {'up': 1, 'people': 1},
#  'cushion': {'and': 1, 'resting': 1},
#  'altogether': {'alice': 1, 'for': 1, 'like': 1, 'but': 1, 'that': 1},
#  'nasty': {'low': 1},
#  'babythe': {'fireirons': 1},
#  'bat': {'and': 1, 'how': 1, 'when': 1},
#  'nicely': {'straightened': 1, 'by': 1},
#  'anxiously': {'among': 1,
#   'about': 2,
#   'into': 2,
#   'round': 2,
#   'looking': 1,
#   'to': 1,
#   'at': 2,
#   'yes': 1,
#   'fixed': 1,
#   'over': 1},
#  'shape': {'doesnt': 1},
#  'licking': {'her': 1},
#  'twice': {'and': 1, 'each': 1, 'set': 1, 'she': 1, 'half': 1},
#  'bad': {'cold': 1, 'that': 1},
#  'softly': {'after': 1},
#  'lookingglass': {'there': 1},
#  'explanations': {'take': 1},
#  'ears': {'and': 2, 'the': 1, 'have': 1, 'for': 1},
#  'blew': {'three': 2},
#  'fair': {'warning': 1},
#  'depends': {'a': 1},
#  'decided': {'on': 1, 'tone': 1, 'to': 1},
#  'flashed': {'across': 1},
#  'cattle': {'in': 1},
#  'miserable': {'mock': 1, 'hatter': 1},
#  'mournfully': {'not': 1},
#  'best': {'butter': 2,
#   'afore': 1,
#   'for': 1,
#   'thing': 1,
#   'of': 1,
#   'some': 1,
#   'cat': 1,
#   'to': 1,
#   'plan': 1,
#   'way': 2},
#  'subject': {'go': 1, 'our': 1, 'the': 1, 'ten': 1, 'of': 2},
#  'pebbles': {'came': 1, 'were': 1},
#  'said': {'and': 5,
#   'seven': 1,
#   'right': 1,
#   'consider': 1,
#   'just': 1,
#   'gravely': 1,
#   'it': 3,
#   'pig': 1,
#   'as': 2,
#   'aliceand': 1,
#   'im': 1,
#   'at': 1,
#   'in': 8,
#   'everybody': 1,
#   'what': 2,
#   'i': 4,
#   'for': 2,
#   'no': 2,
#   'get': 1,
#   'tossing': 1,
#   'two': 1,
#   'by': 1,
#   'to': 39,
#   'that': 1,
#   'which': 1,
#   'advance': 1,
#   'was': 1,
#   'poor': 1,
#   'his': 2,
#   'turning': 3,
#   'severely': 1,
#   'very': 4,
#   'after': 1,
#   'but': 1,
#   'waving': 1,
#   'five': 3,
#   'fifteenth': 1,
#   'nothing': 6,
#   'he': 1,
#   'one': 1,
#   'with': 3,
#   'than': 1,
#   'cunning': 1,
#   'a': 3,
#   'on': 1,
#   'her': 1,
#   'this': 6,
#   'anxiously': 1,
#   'alice': 115,
#   'these': 1,
#   'without': 2,
#   'so': 2,
#   'aloud': 1,
#   'the': 210,
#   'theres': 1,
#   'thats': 2},
#  'away': {'quietly': 1,
#   'consider': 1,
#   'into': 1,
#   'some': 1,
#   'comfortably': 1,
#   'in': 1,
#   'even': 1,
#   'from': 2,
#   'come': 1,
#   'there': 1,
#   'when': 1,
#   'under': 1,
#   'you': 1,
#   'but': 1,
#   'besides': 1,
#   'altogether': 1,
#   'with': 1,
#   'went': 1,
#   'without': 2,
#   'she': 1,
#   'the': 2,
#   'my': 1},
#  'listeners': {'were': 1},
#  'unable': {'to': 1},
#  'finger': {'very': 1, 'and': 1, 'as': 1, 'pressed': 1, 'for': 1},
#  'sorts': {'of': 3},
#  'claws': {'and': 2},
#  'crossly': {'of': 1},
#  'interrupting': {'it': 1, 'him': 1},
#  'terms': {'with': 1},
#  'confusion': {'of': 1, 'as': 1, 'he': 1, 'getting': 1, 'that': 1},
#  'weak': {'voice': 1, 'for': 1},
#  'however': {'on': 1,
#   'ive': 1,
#   'this': 1,
#   'when': 1,
#   'it': 3,
#   'jurymen': 1,
#   'everything': 1,
#   'she': 6,
#   'they': 1,
#   'the': 2,
#   'he': 1,
#   'at': 1},
#  'camomile': {'that': 1},
#  'twinkling': {'begins': 1, 'of': 2, 'halfpast': 1},
#  'drew': {'a': 1, 'all': 1, 'herself': 1, 'the': 1, 'her': 1},
#  'picking': {'the': 1, 'them': 1},
#  'maynt': {'believe': 1},
#  'improve': {'his': 1},
#  'pity': {'i': 1, 'the': 1, 'it': 1},
#  'received': {'knife': 1},
#  'accident': {'of': 1, 'all': 1},
#  'goodnatured': {'she': 1},
#  'country': {'is': 1},
#  'ill': {'set': 1,
#   'just': 1,
#   'give': 2,
#   'manage': 1,
#   'soon': 1,
#   'have': 4,
#   'go': 1,
#   'write': 1,
#   'take': 1,
#   'tell': 3,
#   'kick': 1,
#   'be': 2,
#   'get': 1,
#   'never': 1,
#   'stay': 2,
#   'put': 1,
#   'come': 1,
#   'eat': 1,
#   'look': 1,
#   'alice': 1,
#   'try': 3,
#   'so': 1,
#   'fetch': 1},
#  'cup': {'of': 1, 'interrupted': 1},
#  'adventures': {'from': 1, 'i': 1, 'of': 1, 'till': 1, 'in': 1, 'first': 1},
#  'edgar': {'atheling': 1},
#  'players': {'and': 1, 'to': 1, 'all': 1, 'except': 1},
#  'games': {'now': 1, 'going': 1},
#  'treacle': {'said': 3, 'from': 1, 'out': 1},
#  'argue': {'its': 1},
#  'asked': {'begin': 1,
#   'we': 1,
#   'your': 1,
#   'oh': 1,
#   'no': 1,
#   'it': 1,
#   'why': 1,
#   'that': 1,
#   'triumphantly': 1,
#   'another': 1,
#   'in': 1,
#   'the': 3,
#   'with': 1,
#   'yes': 1,
#   'alice': 1},
#  'tone': {'and': 6,
#   'seven': 1,
#   'dont': 1,
#   'it': 1,
#   'as': 1,
#   'im': 1,
#   'at': 1,
#   'for': 1,
#   'sit': 1,
#   'pray': 1,
#   'only': 1,
#   'going': 1,
#   'was': 1,
#   'tell': 1,
#   'nobody': 1,
#   'though': 1,
#   'exactly': 1,
#   'but': 1,
#   'hm': 1,
#   'why': 2,
#   'he': 2,
#   'of': 7,
#   'alice': 1,
#   'so': 1,
#   'the': 1,
#   'explanations': 1,
#   'are': 1},
#  'appeared': {'and': 2,
#   'on': 1,
#   'again': 1,
#   'i': 1,
#   'but': 1,
#   'to': 1,
#   'she': 1},
#  'royal': {'children': 2},
#  'backsomersault': {'in': 1},
#  'lullaby': {'to': 1},
#  'height': {'to': 2, 'as': 1, 'it': 1, 'indeed': 1},
#  'wider': {'come': 1},
#  'beheaded': {'and': 1, 'what': 1, 'said': 1},
#  'speak': {'and': 1,
#   'again': 2,
#   'what': 1,
#   'good': 1,
#   'severely': 1,
#   'roughly': 1,
#   'but': 1,
#   'to': 1,
#   'a': 1,
#   'english': 1,
#   'not': 1,
#   'with': 1,
#   'first': 1},
#  'shouting': {'off': 2},
#  'remained': {'looking': 1, 'the': 1, 'some': 1},
#  'three': {'and': 1,
#   'dates': 1,
#   'pairs': 1,
#   'or': 1,
#   'inches': 2,
#   'of': 3,
#   'little': 2,
#   'times': 1,
#   'to': 1,
#   'questions': 1,
#   'were': 1,
#   'gardeners': 6,
#   'soldiers': 1,
#   'weeks': 1,
#   'blasts': 2,
#   'your': 1},
#  'been': {'examining': 1,
#   'all': 1,
#   'changed': 4,
#   'doing': 1,
#   'it': 1,
#   'picked': 1,
#   'in': 1,
#   'before': 1,
#   'would': 1,
#   'looking': 2,
#   'to': 3,
#   'reading': 1,
#   'was': 1,
#   'that': 1,
#   'but': 1,
#   'broken': 1,
#   'running': 1,
#   'jumping': 1,
#   'a': 2,
#   'for': 1,
#   'anything': 1,
#   'of': 1,
#   'invited': 1,
#   'anxiously': 1,
#   'annoyed': 1,
#   'so': 1,
#   'found': 1,
#   'the': 2,
#   'wandering': 1,
#   'ill': 1},
#  'quarrelling': {'all': 1, 'with': 1},
#  'chimneys': {'were': 1},
#  'much': {'already': 1,
#   'indeed': 1,
#   'into': 1,
#   'confused': 1,
#   'evidence': 1,
#   'tonight': 1,
#   'as': 3,
#   'right': 1,
#   'at': 2,
#   'ifif': 1,
#   'frightened': 2,
#   'pleased': 1,
#   'out': 1,
#   'what': 1,
#   'said': 4,
#   'from': 1,
#   'farther': 1,
#   'to': 1,
#   'under': 1,
#   'so': 1,
#   'surprised': 2,
#   'more': 1,
#   'pepper': 1,
#   'contradicted': 1,
#   'use': 1,
#   'sooner': 1,
#   'alas': 1,
#   'overcome': 1,
#   'care': 1,
#   'about': 1,
#   'like': 1,
#   'of': 3,
#   'larger': 1,
#   'thought': 1,
#   'matter': 1,
#   'accustomed': 1,
#   'she': 1,
#   'the': 3,
#   'pleasanter': 1},
#  'axis': {'talking': 1},
#  'teaparty': {'chapter': 1, 'i': 1, 'there': 1},
#  'schoolroom': {'and': 1},
#  'expected': {'before': 1},
#  'firstverdict': {'afterwards': 1},
#  'lovely': {'garden': 2},
#  'knowno': {'more': 1},
#  'threw': {'a': 1, 'themselves': 1},
#  'life': {'and': 1,
#   'just': 1,
#   'i': 1,
#   'indeed': 1,
#   'never': 1,
#   'it': 1,
#   'to': 1,
#   'she': 1,
#   'you': 1,
#   'the': 1,
#   'before': 1},
#  'wags': {'its': 1},
#  'mushroom': {'and': 3, 'said': 1, 'for': 1, 'she': 1, 'in': 1, 'growing': 1},
#  'twinkled': {'after': 1},
#  'grunt': {'said': 1},
#  'uncommon': {'nonsense': 1},
#  'nowbut': {'im': 1},
#  'child': {'again': 1,
#   'said': 2,
#   'for': 1,
#   'was': 1,
#   'away': 1,
#   'but': 2,
#   'the': 1,
#   'my': 1},
#  'catch': {'a': 2, 'hold': 1},
#  'doth': {'the': 3},
#  'teapot': {'at': 1},
#  'rabbitspat': {'pat': 1},
#  'tide': {'rises': 1},
#  'has': {'a': 1, 'just': 1, 'lasted': 1, 'won': 2, 'become': 1, 'he': 1},
#  'lessen': {'from': 1},
#  'tastes': {'sing': 1},
#  'air': {'even': 1,
#   'do': 1,
#   'and': 2,
#   'off': 1,
#   'this': 1,
#   'of': 1,
#   'it': 1,
#   'as': 1,
#   'im': 1,
#   'are': 1,
#   'mixed': 1,
#   'if': 1,
#   'she': 1},
#  'aim': {'a': 1},
#  'ugly': {'and': 1, 'child': 1},
#  'near': {'our': 1, 'the': 10, 'here': 1, 'her': 2, 'enough': 1},
#  'neat': {'little': 1},
#  'viii': {'the': 2},
#  'stopping': {'herself': 1},
#  'voice': {'and': 6,
#   'alongcatch': 1,
#   'back': 1,
#   'at': 1,
#   'in': 1,
#   'close': 1,
#   'your': 1,
#   'if': 1,
#   'are': 1,
#   'what': 1,
#   'would': 1,
#   'nobody': 1,
#   'behind': 1,
#   'same': 1,
#   'to': 3,
#   'outside': 1,
#   'has': 1,
#   'until': 1,
#   'repeat': 1,
#   'who': 1,
#   'but': 1,
#   'let': 1,
#   'not': 1,
#   'now': 1,
#   'why': 1,
#   'died': 1,
#   'i': 2,
#   'of': 5,
#   'sometimes': 1,
#   'sounded': 1,
#   'she': 1,
#   'the': 1,
#   'theres': 1,
#   'fetch': 1,
#   'thats': 1},
#  'mistake': {'and': 1, 'about': 1, 'it': 1},
#  'remembering': {'her': 1},
#  'ix': {'the': 2},
#  'seven': {'said': 1,
#   'isoh': 1,
#   'flung': 1,
#   'looked': 1,
#   'yes': 1,
#   'jogged': 1},
#  'fourteenth': {'of': 1},
#  'played': {'at': 1},
#  'linked': {'into': 1},
#  'is': {'twelve': 1,
#   'his': 2,
#   'bill': 1,
#   'just': 1,
#   'blown': 1,
#   'almost': 1,
#   'over': 1,
#   'it': 9,
#   'as': 1,
#   'right': 1,
#   'asleep': 1,
#   'thirteen': 1,
#   'another': 1,
#   'queer': 1,
#   'its': 1,
#   'if': 1,
#   'what': 2,
#   'said': 2,
#   'no': 1,
#   'rather': 1,
#   'only': 1,
#   'to': 6,
#   'enough': 1,
#   'which': 1,
#   'you': 4,
#   'today': 1,
#   'then': 1,
#   'all': 1,
#   'sure': 1,
#   'may': 1,
#   'gay': 1,
#   'that': 6,
#   'very': 1,
#   'who': 1,
#   'but': 1,
#   'wrong': 1,
#   'here': 1,
#   'not': 1,
#   'such': 4,
#   'why': 1,
#   'look': 1,
#   'a': 5,
#   'made': 1,
#   'like': 1,
#   'this': 2,
#   'of': 4,
#   'ill': 1,
#   'dinah': 1,
#   'alice': 1,
#   'i': 4,
#   'so': 1,
#   'the': 11,
#   'narrow': 1,
#   'something': 1},
#  'it': {'directed': 1,
#   'all': 4,
#   'looked': 1,
#   'just': 4,
#   'over': 4,
#   'stays': 1,
#   'isnt': 4,
#   'behind': 1,
#   'yer': 1,
#   'its': 1,
#   'seemed': 2,
#   'busily': 1,
#   'seems': 2,
#   'except': 1,
#   'should': 1,
#   'to': 10,
#   'only': 1,
#   'belongs': 2,
#   'he': 4,
#   'might': 8,
#   'pointed': 1,
#   'ought': 2,
#   'gave': 1,
#   'meant': 1,
#   'then': 2,
#   'presently': 1,
#   'kills': 1,
#   'means': 3,
#   'very': 3,
#   'panting': 1,
#   'muttering': 1,
#   'matters': 1,
#   'every': 1,
#   'marked': 1,
#   'they': 3,
#   'altogether': 1,
#   'now': 2,
#   'continued': 1,
#   'you': 4,
#   'wont': 1,
#   'chuckled': 1,
#   'did': 2,
#   'alice': 1,
#   'unfolded': 1,
#   'she': 7,
#   'further': 1,
#   'went': 3,
#   'twelve': 1,
#   'set': 1,
#   'old': 1,
#   'back': 2,
#   'hurried': 1,
#   'up': 2,
#   'shes': 1,
#   'cant': 1,
#   'home': 1,
#   'yet': 1,
#   'out': 6,
#   'even': 1,
#   'what': 1,
#   'said': 22,
#   'for': 2,
#   'away': 3,
#   'please': 2,
#   'hastily': 1,
#   'written': 2,
#   'does': 3,
#   'goes': 2,
#   'got': 1,
#   'trot': 1,
#   'be': 2,
#   'felt': 1,
#   'led': 1,
#   'chose': 1,
#   'right': 1,
#   'arrum': 1,
#   'never': 1,
#   'here': 1,
#   'quite': 2,
#   'put': 2,
#   'on': 1,
#   'about': 1,
#   'last': 1,
#   'her': 1,
#   'wouldnt': 1,
#   'oh': 1,
#   'could': 1,
#   'usually': 1,
#   'makes': 3,
#   'or': 2,
#   'first': 1,
#   'dont': 1,
#   'suddenly': 1,
#   'had': 17,
#   'into': 2,
#   'explained': 1,
#   'pop': 1,
#   'down': 2,
#   'doesnt': 7,
#   'puffed': 1,
#   'likes': 1,
#   'sounds': 1,
#   'uneasily': 1,
#   'appeared': 1,
#   'muttered': 1,
#   'spoke': 2,
#   'would': 15,
#   'there': 4,
#   'signifies': 1,
#   'ran': 1,
#   'much': 1,
#   'too': 2,
#   'meanstomakeanythingprettier': 1,
#   'was': 74,
#   'woke': 1,
#   'more': 1,
#   'that': 1,
#   'occurred': 2,
#   'but': 6,
#   'teases': 1,
#   'hadnt': 1,
#   'trying': 1,
#   'must': 7,
#   'begins': 1,
#   'myself': 1,
#   'made': 2,
#   'this': 1,
#   'as': 9,
#   'flashed': 1,
#   'will': 1,
#   'matter': 1,
#   'while': 2,
#   'exclaimed': 1,
#   'can': 2,
#   'were': 2,
#   'advisable': 2,
#   'didnt': 2,
#   'at': 4,
#   'and': 26,
#   'wasnt': 3,
#   'is': 18,
#   'turned': 3,
#   'it': 2,
#   'sad': 1,
#   'really': 1,
#   'say': 2,
#   'proves': 1,
#   'im': 1,
#   'something': 1,
#   'in': 11,
#   'gloomily': 1,
#   'watched': 1,
#   'mouse': 1,
#   'tells': 1,
#   'sat': 2,
#   'again': 4,
#   'hasnt': 1,
#   'no': 1,
#   'rather': 1,
#   'saw': 2,
#   'began': 2,
#   'puzzled': 2,
#   'when': 2,
#   'any': 1,
#   'how': 1,
#   'which': 2,
#   'before': 1,
#   'vanished': 1,
#   'if': 1,
#   'happens': 1,
#   'added': 1,
#   'may': 1,
#   'stop': 1,
#   'after': 1,
#   'purring': 1,
#   'pleaded': 2,
#   'why': 1,
#   'grunted': 1,
#   'a': 6,
#   'off': 3,
#   'fills': 1,
#   'i': 6,
#   'settled': 1,
#   'tricks': 1,
#   'well': 1,
#   'lasted': 1,
#   'asked': 1,
#   'thought': 1,
#   'so': 6,
#   'aloud': 1,
#   'the': 4,
#   'thats': 2,
#   'sounded': 1,
#   'fitted': 1,
#   'left': 1},
#  'iv': {'the': 2},
#  'ii': {'the': 2, 'hardly': 1},
#  'gloomily': {'then': 1},
#  'cant': {'swim': 1,
#   'be': 2,
#   'remember': 4,
#   'get': 1,
#   'explain': 2,
#   'show': 1,
#   'go': 1,
#   'tell': 1,
#   'prove': 1,
#   'possibly': 1,
#   'see': 1,
#   'understand': 1,
#   'take': 2,
#   'have': 1,
#   'put': 1,
#   'hear': 1,
#   'quite': 1,
#   'think': 2,
#   'help': 3},
#  'im': {'certain': 1,
#   'doubtful': 1,
#   'talking': 1,
#   'mabel': 1,
#   'pleased': 1,
#   'grown': 1,
#   'afraid': 7,
#   'angry': 1,
#   'better': 1,
#   'going': 1,
#   'too': 1,
#   'perfectly': 1,
#   'sure': 6,
#   'somebody': 1,
#   'opening': 1,
#   'very': 1,
#   'never': 1,
#   'here': 1,
#   'quite': 1,
#   'mad': 3,
#   'not': 9,
#   'glad': 3,
#   'a': 6,
#   'on': 2,
#   'getting': 1,
#   'i': 1,
#   'aim': 1,
#   'growing': 1},
#  'clinging': {'close': 1},
#  'in': {'saying': 1,
#   'currants': 1,
#   'less': 1,
#   'all': 5,
#   'large': 1,
#   'questions': 1,
#   'ringlets': 1,
#   'existence': 1,
#   'its': 2,
#   'before': 1,
#   'spite': 1,
#   'to': 1,
#   'crying': 1,
#   'prison': 1,
#   'them': 1,
#   'his': 5,
#   'march': 1,
#   'reply': 5,
#   'front': 2,
#   'bringing': 1,
#   'like': 1,
#   'chorus': 1,
#   'this': 4,
#   'she': 2,
#   'bills': 1,
#   'some': 2,
#   'books': 1,
#   'sight': 3,
#   'wonderland': 2,
#   'coils': 1,
#   'managing': 1,
#   'waiting': 1,
#   'asking': 1,
#   'surprise': 1,
#   'chains': 1,
#   'confusion': 1,
#   'here': 2,
#   'by': 1,
#   'search': 1,
#   'getting': 1,
#   'despair': 1,
#   'asked': 1,
#   'silence': 3,
#   'among': 1,
#   'knocking': 1,
#   'one': 3,
#   'another': 7,
#   'your': 2,
#   'custody': 1,
#   'her': 15,
#   'there': 1,
#   'their': 5,
#   'head': 1,
#   'that': 8,
#   'great': 2,
#   'but': 1,
#   'particular': 2,
#   'trying': 1,
#   'with': 3,
#   'livery': 3,
#   'these': 1,
#   'bed': 1,
#   'about': 1,
#   'my': 9,
#   'it': 8,
#   'an': 10,
#   'couples': 1,
#   'talking': 1,
#   'as': 1,
#   'at': 5,
#   'any': 1,
#   'curving': 1,
#   'dancing': 1,
#   'rather': 1,
#   'things': 1,
#   'same': 1,
#   'which': 4,
#   'hand': 2,
#   'such': 4,
#   'a': 98,
#   'without': 1,
#   'fact': 4,
#   'time': 4,
#   'the': 79,
#   'salt': 1,
#   'contemptuous': 1},
#  'importantunimportantunimportantimportant': {'as': 1},
#  'mouse': {'replied': 1,
#   'heard': 1,
#   'doesnt': 1,
#   'in': 2,
#   'dear': 1,
#   'to': 3,
#   'come': 1,
#   'had': 1,
#   'everything': 1,
#   'only': 2,
#   'you': 1,
#   'was': 3,
#   'gave': 1,
#   'do': 1,
#   'splashed': 1,
#   'turning': 1,
#   'that': 2,
#   'who': 2,
#   'frowning': 1,
#   'sharply': 1,
#   'with': 1,
#   'getting': 1,
#   'i': 1,
#   'of': 1,
#   'alice': 1,
#   'looked': 1,
#   'did': 2,
#   'she': 1,
#   'the': 1},
#  'id': {'gone': 1,
#   'rather': 2,
#   'been': 1,
#   'better': 1,
#   'only': 1,
#   'nearly': 2,
#   'have': 1,
#   'taken': 1,
#   'hardly': 1},
#  'if': {'ive': 2,
#   'people': 1,
#   'youd': 2,
#   'it': 10,
#   'one': 1,
#   'not': 1,
#   'im': 2,
#   'something': 1,
#   'id': 1,
#   'everybody': 1,
#   'there': 2,
#   'any': 1,
#   'only': 1,
#   'you': 22,
#   'we': 1,
#   'his': 1,
#   'they': 2,
#   'nothing': 1,
#   'he': 6,
#   'a': 2,
#   'anything': 1,
#   'i': 16,
#   'youre': 1,
#   'she': 9,
#   'youve': 1,
#   'the': 2,
#   'theres': 1,
#   'my': 1,
#   'thats': 1},
#  'grown': {'woman': 1, 'to': 1, 'up': 2, 'most': 1, 'so': 1, 'in': 1},
#  'growl': {'and': 1, 'the': 1, 'when': 1},
#  'severity': {'its': 1},
#  'things': {'and': 1,
#   'all': 2,
#   'dont': 1,
#   'being': 1,
#   'had': 1,
#   'twinkled': 1,
#   'as': 1,
#   'are': 2,
#   'in': 1,
#   'its': 1,
#   'said': 1,
#   'get': 1,
#   'when': 2,
#   'to': 1,
#   'indeed': 1,
#   'that': 1,
#   'between': 1,
#   'on': 1,
#   'happening': 1,
#   'i': 1,
#   'of': 1,
#   'alice': 2,
#   'went': 1,
#   'at': 1},
#  'make': {'me': 4,
#   'their': 1,
#   'personal': 1,
#   'with': 1,
#   'some': 1,
#   'it': 1,
#   'one': 3,
#   'children': 1,
#   'you': 4,
#   'herself': 1,
#   'the': 1,
#   'out': 7},
#  'breadandbutter': {'and': 2, 'getting': 1, 'but': 1, 'just': 1, 'in': 1},
#  'forehead': {'ache': 1, 'the': 1},
#  'unfortunate': {'gardeners': 1, 'little': 1, 'guests': 1},
#  'vegetable': {'it': 1},
#  'plates': {'and': 2},
#  'several': {'things': 1, 'times': 1, 'other': 1, 'nice': 1},
#  'couple': {'you': 1},
#  'fairly': {'alice': 1},
#  'teathings': {'are': 1},
#  'tops': {'of': 1},
#  'hand': {'and': 6,
#   'on': 1,
#   'said': 1,
#   'again': 1,
#   'watching': 1,
#   'upon': 1,
#   'it': 2,
#   'in': 4,
#   'with': 1,
#   'round': 1,
#   'if': 1},
#  'delight': {'and': 1, 'it': 1, 'which': 1},
#  'marched': {'off': 1},
#  'dozing': {'off': 1},
#  'opportunity': {'of': 4, 'for': 4},
#  'thoughts': {'she': 1, 'were': 1},
#  'kid': {'gloves': 5},
#  'butter': {'the': 1, 'you': 1, 'wouldnt': 1},
#  'hearth': {'and': 1},
#  'kept': {'a': 1,
#   'on': 2,
#   'fanning': 1,
#   'from': 1,
#   'her': 2,
#   'getting': 1,
#   'tossing': 1,
#   'all': 1,
#   'running': 1,
#   'shifting': 1,
#   'doubling': 1},
#  'matters': {'a': 1, 'it': 1},
#  'settled': {'down': 3},
#  'youre': {'a': 3,
#   'nothing': 1,
#   'sure': 1,
#   'talking': 1,
#   'doing': 1,
#   'nervous': 1,
#   'changed': 1,
#   'wrong': 1,
#   'thinking': 1,
#   'looking': 1,
#   'to': 1,
#   'enough': 1,
#   'going': 1,
#   'so': 1,
#   'mad': 2,
#   'wondering': 1,
#   'growing': 1,
#   'falling': 1,
#   'trying': 1,
#   'at': 1},
#  'bankthe': {'birds': 1},
#  'rome': {'and': 1},
#  'humbly': {'i': 1, 'you': 1},
#  'impertinent': {'said': 1},
#  'hearts': {'and': 1,
#   'who': 1,
#   'alice': 1,
#   'next': 1,
#   'carrying': 1,
#   'she': 1,
#   'were': 1,
#   'he': 1},
#  'the': {'whiting': 4,
#   'dance': 10,
#   'pigeon': 11,
#   'month': 2,
#   'dish': 1,
#   'oldest': 1,
#   'children': 1,
#   'cupboards': 1,
#   'lory': 6,
#   'young': 3,
#   'passage': 1,
#   'tail': 1,
#   'sound': 1,
#   'garden': 9,
#   'song': 4,
#   'very': 2,
#   'hatter': 51,
#   'spoon': 1,
#   'fan': 6,
#   'fall': 2,
#   'cook': 12,
#   'trouble': 1,
#   'lefthand': 2,
#   'cool': 1,
#   'shock': 1,
#   'list': 3,
#   'large': 1,
#   'sand': 1,
#   'race': 2,
#   'small': 1,
#   'rabbits': 3,
#   'insolence': 1,
#   'rats': 1,
#   'ten': 1,
#   'tea': 2,
#   'procession': 3,
#   'boots': 2,
#   'second': 3,
#   'reedsthe': 1,
#   'earth': 4,
#   'further': 1,
#   'creatures': 3,
#   'what': 1,
#   'darkness': 1,
#   'clock': 2,
#   'sun': 1,
#   'lizard': 4,
#   'experiment': 2,
#   'capital': 2,
#   'babythe': 1,
#   'melancholy': 1,
#   'jury': 15,
#   'water': 1,
#   'soldiers': 6,
#   'twentieth': 1,
#   'others': 5,
#   'directions': 1,
#   'shriek': 2,
#   'change': 1,
#   'box': 1,
#   'great': 6,
#   'leaves': 2,
#   'gryphon': 53,
#   'trial': 4,
#   'mouses': 1,
#   'patriotic': 1,
#   'mistake': 1,
#   'wig': 1,
#   'dormouse': 34,
#   'patience': 1,
#   'moral': 6,
#   'guests': 1,
#   'duck': 2,
#   'pepperbox': 1,
#   'use': 4,
#   'jurors': 3,
#   'breadknife': 1,
#   'archbishop': 1,
#   'two': 3,
#   'next': 13,
#   'dormouses': 1,
#   'lock': 1,
#   'eaglet': 2,
#   'sort': 4,
#   'entrance': 1,
#   'door': 20,
#   'company': 1,
#   'glass': 3,
#   'prizes': 1,
#   'rabbit': 19,
#   'baby': 10,
#   'circumstances': 1,
#   'balls': 1,
#   'animals': 1,
#   'room': 3,
#   'footmans': 1,
#   'dodo': 12,
#   'roof': 6,
#   'cat': 21,
#   'soup': 1,
#   'arches': 2,
#   'slightest': 1,
#   'beautiful': 1,
#   'rosetree': 2,
#   'shark': 1,
#   'unjust': 1,
#   'confused': 1,
#   'pieces': 1,
#   'locks': 1,
#   'sense': 1,
#   'bones': 1,
#   'trumpet': 2,
#   'rabbithole': 3,
#   'thing': 3,
#   'hot': 1,
#   'fourth': 1,
#   'footman': 7,
#   'answer': 3,
#   'creature': 1,
#   'waters': 1,
#   'spot': 1,
#   'multiplication': 1,
#   'end': 12,
#   'law': 1,
#   'arch': 1,
#   'hedgehogs': 2,
#   'sluggard': 1,
#   'branches': 1,
#   'neck': 1,
#   'tale': 1,
#   'chief': 1,
#   'shade': 1,
#   'things': 4,
#   'pleasure': 1,
#   'dream': 1,
#   'order': 1,
#   'wind': 2,
#   'hedgehog': 4,
#   'course': 1,
#   'paper': 2,
#   'crumbs': 1,
#   'birds': 3,
#   'roots': 1,
#   'queerest': 1,
#   'exact': 1,
#   'window': 7,
#   'setting': 1,
#   'lookout': 1,
#   'roses': 2,
#   'evening': 2,
#   'slate': 1,
#   'caterpillar': 25,
#   'hall': 5,
#   'bank': 2,
#   'name': 6,
#   'corners': 1,
#   'croquetground': 1,
#   'truth': 1,
#   'breeze': 1,
#   'house': 12,
#   'idea': 1,
#   'goose': 1,
#   'sands': 1,
#   'blows': 1,
#   'witness': 1,
#   'open': 1,
#   'eeevening': 3,
#   'hatters': 1,
#   'millennium': 1,
#   'cause': 1,
#   'lookingglass': 1,
#   'story': 1,
#   'puppys': 1,
#   'reason': 7,
#   'doubledup': 1,
#   'mallets': 1,
#   'beginning': 3,
#   'shelves': 1,
#   'flurry': 1,
#   'conversation': 3,
#   'place': 3,
#   'porpoise': 1,
#   'first': 16,
#   'number': 2,
#   'one': 1,
#   'eleventh': 1,
#   'sounds': 1,
#   'woodshe': 1,
#   'frogfootman': 1,
#   'executioners': 1,
#   'little': 19,
#   'heads': 1,
#   'lap': 1,
#   'top': 8,
#   'least': 2,
#   'master': 2,
#   'white': 22,
#   'legs': 1,
#   'eyes': 1,
#   'immediate': 1,
#   'part': 1,
#   'flowers': 1,
#   'stairs': 1,
#   'king': 60,
#   'youth': 3,
#   'matter': 3,
#   'flame': 1,
#   'wandering': 1,
#   'executioner': 5,
#   'thistle': 1,
#   'tarts': 4,
#   'rattle': 1,
#   'ceiling': 1,
#   'tide': 1,
#   'groundand': 1,
#   'thought': 2,
#   'jurybox': 4,
#   'doori': 1,
#   'shore': 2,
#   'subjects': 1,
#   'hookah': 4,
#   'doors': 1,
#   'blades': 1,
#   'centre': 1,
#   'eggs': 1,
#   'most': 4,
#   'regular': 1,
#   'mouth': 1,
#   'pair': 1,
#   'queens': 8,
#   'm': 1,
#   'face': 1,
#   'pattern': 1,
#   'salt': 1,
#   'duchesss': 3,
#   'pope': 1,
#   'queen': 65,
#   'sage': 1,
#   'guineapigs': 2,
#   'bright': 2,
#   'corner': 1,
#   'fifth': 1,
#   'ground': 4,
#   'otherbill': 1,
#   'nearer': 1,
#   'busy': 1,
#   'sentence': 1,
#   'jar': 1,
#   'only': 4,
#   'wood': 6,
#   'deepest': 1,
#   'shrill': 1,
#   'shepherd': 1,
#   'shinglewill': 1,
#   'distance': 7,
#   'squeaking': 1,
#   'watch': 1,
#   'trees': 6,
#   'words': 12,
#   'beak': 1,
#   'hedge': 2,
#   'banquet': 1,
#   'chimney': 5,
#   'brain': 1,
#   'morning': 1,
#   'cheshire': 3,
#   'gloves': 1,
#   'common': 1,
#   'pigbaby': 1,
#   'sea': 9,
#   'cattle': 1,
#   'miserable': 2,
#   'arm': 1,
#   'best': 8,
#   'subject': 4,
#   'pebbles': 1,
#   'pictures': 1,
#   'outside': 1,
#   'smallest': 2,
#   'court': 15,
#   'blame': 1,
#   'key': 2,
#   'singers': 1,
#   'suppressed': 1,
#   'kitchen': 2,
#   'twinkling': 2,
#   'accident': 2,
#   'last': 6,
#   'country': 1,
#   'stupidest': 1,
#   'panther': 3,
#   'adventures': 1,
#   'nile': 1,
#   'players': 3,
#   'doorway': 1,
#   'games': 2,
#   'whole': 13,
#   'riddle': 1,
#   'cakes': 1,
#   'tone': 1,
#   'simple': 2,
#   'royal': 2,
#   'accusation': 1,
#   'goldfish': 1,
#   'kings': 2,
#   'lizards': 1,
#   'three': 7,
#   'tiny': 1,
#   'chimneys': 1,
#   'treat': 1,
#   'schoolroom': 1,
#   'proposal': 1,
#   'meeting': 1,
#   'direction': 2,
#   'mushroom': 5,
#   'fire': 3,
#   'wretched': 1,
#   'teapot': 1,
#   'case': 1,
#   'look': 4,
#   'turtles': 1,
#   'bill': 1,
#   'air': 10,
#   'while': 2,
#   'antipathies': 1,
#   'fun': 1,
#   'voice': 4,
#   'pack': 1,
#   'middle': 6,
#   'sudden': 1,
#   'mouse': 27,
#   'different': 1,
#   'righthand': 2,
#   'choking': 1,
#   'fishfootman': 2,
#   'fender': 1,
#   'same': 21,
#   'breadandbutter': 2,
#   'strange': 1,
#   'unfortunate': 2,
#   'largest': 1,
#   'party': 4,
#   'twelfth': 1,
#   'week': 1,
#   'snail': 1,
#   'tops': 1,
#   'effect': 2,
#   'hand': 1,
#   'moment': 8,
#   'opportunity': 2,
#   'hearth': 1,
#   'well': 3,
#   'bankthe': 1,
#   'edge': 3,
#   'frontispiece': 1,
#   'bottle': 3,
#   'english': 2,
#   'position': 1,
#   'the': 1,
#   'lobsters': 4,
#   'less': 1,
#   'loveliest': 1,
#   'rest': 8,
#   'officers': 4,
#   'verses': 3,
#   'distant': 2,
# ...
#   'also': 1,
#   'your': 1,
#   'if': 1,
#   'her': 5,
#   'eager': 1,
#   'to': 2,
#   'goes': 1,
#   'eyes': 1,
#   'somebody': 1,
#   'but': 1,
#   'lives': 1,
#   'a': 1,
#   'on': 1,
#   'i': 1,
#   'ill': 1,
#   'alice': 1,
#   'face': 1,
#   'she': 2,
#   'the': 8},
#  'prevent': {'its': 1},
#  'brave': {'theyll': 1},
#  'says': {'youre': 1, 'come': 1, 'its': 1, 'it': 1},
#  'tougher': {'than': 1},
#  'sigh': {'i': 2, 'its': 1, 'he': 1},
#  'sign': {'it': 1},
#  'fairytales': {'i': 1},
#  'cost': {'them': 1},
#  'dried': {'her': 1},
#  'dinahll': {'be': 1, 'miss': 1},
#  'helpless': {'sort': 1},
#  'irritated': {'at': 1},
#  'appear': {'and': 1, 'to': 1},
#  'axes': {'said': 1},
#  'lazily': {'about': 1},
#  'goes': {'on': 2, 'his': 1, 'like': 1, 'bill': 1, 'in': 1, 'the': 1},
#  'reply': {'idiot': 1, 'please': 1, 'it': 1, 'for': 1, 'thats': 1},
#  'falling': {'down': 1, 'through': 1},
#  'geography': {'london': 1},
#  'filled': {'the': 1, 'with': 2},
#  'growls': {'when': 1},
#  'jury': {'and': 1,
#   'all': 3,
#   'said': 1,
#   'consider': 1,
#   'of': 1,
#   'who': 1,
#   'had': 1,
#   'eagerly': 1,
#   'asked': 1,
#   'they': 1,
#   'in': 1,
#   'not': 1,
#   'or': 1,
#   'wrote': 1,
#   'if': 1},
#  'partners': {'change': 1},
#  'honour': {'at': 1, 'but': 1, 'digging': 1, 'he': 1},
#  'learn': {'lessons': 1,
#   'oh': 1,
#   'no': 1,
#   'well': 1,
#   'it': 1,
#   'music': 1,
#   'not': 1},
#  'french': {'and': 1, 'lessonbook': 1, 'mouse': 1, 'music': 1},
#  'water': {'and': 1, 'had': 1, 'her': 1, 'out': 1},
#  'twentieth': {'time': 1},
#  'yards': {'off': 1},
#  'elses': {'hand': 1},
#  'hoarse': {'and': 1, 'growl': 1, 'feeble': 1},
#  'along': {'the': 3, 'hand': 1, 'in': 1},
#  'change': {'and': 1,
#   'lobsters': 2,
#   'them': 1,
#   'but': 2,
#   'to': 2,
#   'she': 1,
#   'in': 1,
#   'the': 4},
#  'wait': {'as': 1},
#  'box': {'of': 1, 'allow': 1, 'her': 1, 'that': 1},
#  'sending': {'presents': 1, 'me': 1},
#  'impatiently': {'and': 3, 'any': 1, 'it': 1},
#  'lazy': {'thing': 1},
#  'wherever': {'you': 1, 'she': 1},
#  'gryphon': {'and': 8,
#   'ive': 1,
#   'lifted': 1,
#   'do': 1,
#   'is': 1,
#   'it': 1,
#   'interrupted': 1,
#   'as': 1,
#   'at': 1,
#   'replied': 2,
#   'in': 1,
#   'its': 1,
#   'before': 1,
#   'said': 2,
#   'how': 1,
#   'sighing': 1,
#   'hastily': 1,
#   'answered': 1,
#   'only': 1,
#   'you': 2,
#   'sat': 1,
#   'whispered': 1,
#   'then': 1,
#   'we': 1,
#   'added': 1,
#   'that': 1,
#   'never': 1,
#   'repeated': 1,
#   'they': 1,
#   'half': 1,
#   'with': 1,
#   'the': 2,
#   'i': 2,
#   'of': 1,
#   'well': 1,
#   'alice': 1,
#   'turn': 1,
#   'she': 1,
#   'remarked': 1,
#   'went': 3,
#   'lying': 1},
#  'trial': {'cannot': 1,
#   'for': 1,
#   'is': 1,
#   'one': 1,
#   'stupid': 1,
#   'done': 1,
#   'dear': 1},
#  'usually': {'see': 1, 'bleeds': 1},
#  'shifting': {'from': 1},
#  'quarrel': {'so': 1},
#  'beauootiful': {'soooop': 4},
#  'useful': {'and': 1, 'its': 1},
#  'morals': {'in': 1},
#  'hopeful': {'tone': 1},
#  'merely': {'remarking': 2},
#  'marked': {'out': 1, 'with': 1, 'poison': 3, 'in': 1},
#  'inquisitively': {'and': 1},
#  'puffed': {'away': 1},
#  'swallowed': {'one': 1},
#  'stingy': {'about': 1},
#  'everybody': {'executed': 1,
#   'says': 1,
#   'laughed': 1,
#   'else': 1,
#   'looked': 1,
#   'minded': 1,
#   'minding': 1,
#   'has': 1},
#  'driest': {'thing': 1},
#  'angry': {'and': 1, 'about': 1, 'voicethe': 1, 'tone': 1, 'therefore': 1},
#  'visit': {'either': 1},
#  'tears': {'chapter': 1,
#   'again': 1,
#   'curiouser': 1,
#   'that': 1,
#   'i': 1,
#   'into': 1,
#   'no': 1,
#   'but': 1,
#   'running': 1,
#   'which': 1,
#   'until': 1,
#   'if': 1},
#  'france': {'then': 1},
#  'live': {'ive': 1,
#   'about': 1,
#   'on': 1,
#   'flamingoes': 1,
#   'at': 2,
#   'in': 1,
#   'hedgehogs': 1},
#  'wood': {'for': 1,
#   'is': 1,
#   'to': 1,
#   'the': 1,
#   'continued': 1,
#   'its': 1,
#   'if': 1},
#  'somersault': {'in': 1},
#  'wondering': {'what': 1,
#   'tone': 1,
#   'very': 1,
#   'how': 1,
#   'whether': 1,
#   'why': 1,
#   'if': 1},
#  'teeth': {'so': 1},
#  'today': {'and': 1, 'i': 2, 'just': 1},
#  'loving': {'heart': 1},
#  'chapter': {'ix': 2,
#   'xi': 2,
#   'i': 2,
#   'vi': 2,
#   'vii': 2,
#   'xii': 2,
#   'iv': 2,
#   'ii': 2,
#   'viii': 2,
#   'v': 2,
#   'x': 2,
#   'iii': 2},
#  'entrance': {'of': 1},
#  'sharing': {'a': 1},
#  'afford': {'to': 1},
#  'flying': {'down': 1},
#  'teases': {'chorus': 1},
#  'ignorant': {'little': 1},
#  'fireirons': {'came': 1},
#  'mouseo': {'mouse': 1},
#  'wouldnt': {'be': 3,
#   'squeeze': 1,
#   'mind': 1,
#   'it': 2,
#   'stay': 1,
#   'say': 1,
#   'have': 1,
#   'suit': 1,
#   'keep': 1,
#   'talk': 1},
#  'youall': {'i': 1},
#  'pretend': {'to': 1},
#  'mousea': {'mouseo': 1},
#  'longitude': {'ive': 1, 'either': 1},
#  'cat': {'and': 4,
#   'as': 1,
#   'in': 2,
#   'id': 1,
#   'if': 1,
#   'again': 1,
#   'said': 3,
#   'its': 1,
#   'only': 1,
#   'which': 1,
#   'seemed': 1,
#   'do': 1,
#   'sitting': 1,
#   'may': 1,
#   'remarked': 1,
#   'now': 1,
#   'a': 1,
#   'i': 3,
#   'removed': 1,
#   'dinah': 1,
#   'without': 1,
#   'so': 1,
#   'she': 1,
#   'were': 1,
#   'grins': 1,
#   'went': 1,
#   'or': 1},
#  'soup': {'and': 1,
#   'beauootiful': 2,
#   'off': 1,
#   'of': 2,
#   'is': 1,
#   'who': 1,
#   'pennyworth': 1,
#   'alice': 1,
#   'will': 1,
#   'soup': 1,
#   'beautiful': 1,
#   'does': 1,
#   'so': 1,
#   'chorus': 1,
#   'chapter': 1,
#   'theres': 1},
#  'can': {'all': 1,
#   'be': 2,
#   'say': 1,
#   'have': 2,
#   'go': 1,
#   'find': 3,
#   'creep': 1,
#   'really': 1,
#   'guess': 1,
#   'said': 1,
#   'thoroughly': 1,
#   'explain': 1,
#   'you': 3,
#   'ever': 1,
#   'tell': 1,
#   'kick': 1,
#   'listen': 1,
#   'swim': 1,
#   'do': 2,
#   'draw': 1,
#   'reach': 1,
#   'remember': 1,
#   'i': 2,
#   'hardly': 1,
#   'see': 1,
#   'talk': 1},
#  'growing': {'and': 4,
#   'on': 1,
#   'sometimes': 1,
#   'larger': 1,
#   'near': 1,
#   'too': 1,
#   'youve': 1,
#   'small': 1},
#  'making': {'a': 1,
#   'her': 1,
#   'personal': 1,
#   'quite': 2,
#   'faces': 1,
#   'such': 2},
#  'dispute': {'going': 1, 'with': 1},
#  'laughter': {'oh': 1},
#  'mouses': {'tail': 1},
#  'heart': {'of': 1, 'would': 1},
#  'crazy': {'the': 1},
#  'frontispiece': {'if': 1},
#  'nursing': {'a': 1, 'it': 1, 'her': 1},
#  'figure': {'of': 1, 'said': 2},
#  'carroll': {'the': 1},
#  'confused': {'poor': 1, 'i': 1, 'clamour': 1, 'way': 1},
#  'paused': {'as': 1},
#  'heard': {'a': 5,
#   'yes': 1,
#   'her': 2,
#   'this': 1,
#   'of': 4,
#   'it': 3,
#   'one': 1,
#   'every': 1,
#   'something': 2,
#   'in': 1,
#   'the': 5,
#   'was': 1,
#   'him': 1,
#   'yet': 1,
#   'before': 1},
#  'queerest': {'thing': 1},
#  'chin': {'ive': 1,
#   'into': 1,
#   'upon': 1,
#   'however': 1,
#   'it': 1,
#   'in': 1,
#   'was': 1},
#  'dropped': {'and': 1, 'the': 1, 'his': 1, 'them': 1, 'it': 1},
#  'counting': {'off': 1},
#  'stole': {'the': 2, 'those': 1},
#  'evidently': {'meant': 1},
#  'pink': {'eyes': 1},
#  'rabbithole': {'chapter': 1, 'went': 1, 'alice': 1, 'under': 1},
#  'winter': {'day': 1},
#  'fortunately': {'was': 1},
#  'buttered': {'toast': 1},
#  'watching': {'the': 1, 'them': 1, 'it': 1},
#  'write': {'that': 1, 'this': 1, 'onebut': 1, 'it': 1, 'with': 1, 'out': 1},
#  'till': {'ive': 1,
#   'his': 1,
#   'tomorrow': 1,
#   'im': 1,
#   'she': 10,
#   'you': 1,
#   'the': 3,
#   'now': 1,
#   'its': 1,
#   'at': 1},
#  'fourth': {'two': 1},
#  'stigand': {'the': 1},
#  'condemn': {'you': 1},
#  'may': {'be': 3,
#   'look': 1,
#   'sit': 1,
#   'it': 2,
#   'go': 1,
#   'as': 1,
#   'stand': 1,
#   'kiss': 1,
#   'not': 1,
#   'nurse': 1},
#  'dive': {'in': 1},
#  'spot': {'this': 1},
#  'crashed': {'around': 1},
#  'birthday': {'presents': 1},
#  'tipped': {'over': 1},
#  'mad': {'said': 1,
#   'to': 1,
#   'people': 1,
#   'i': 1,
#   'things': 1,
#   'youre': 1,
#   'here': 1,
#   'how': 1,
#   'as': 1,
#   'but': 1,
#   'teaparty': 2,
#   'you': 2,
#   'after': 1},
#  'such': {'a': 27,
#   'very': 1,
#   'confusion': 1,
#   'sudden': 1,
#   'nonsense': 1,
#   'long': 2,
#   'an': 1,
#   'dainties': 1,
#   'thing': 1,
#   'as': 3,
#   'stuff': 1,
#   'things': 1},
#  'grow': {'shorter': 1,
#   'taller': 1,
#   'smaller': 1,
#   'larger': 2,
#   'up': 3,
#   'here': 1,
#   'large': 1,
#   'to': 1,
#   'at': 1,
#   'any': 1},
#  'man': {'there': 1, 'the': 1, 'said': 1, 'your': 2},
#  'scrambling': {'about': 1},
#  'natural': {'to': 1, 'way': 2, 'but': 1},
#  'remember': {'what': 1,
#   'said': 1,
#   'her': 1,
#   'things': 1,
#   'remarked': 1,
#   'about': 1,
#   'it': 1,
#   'where': 1,
#   'them': 1,
#   'half': 1,
#   'the': 1,
#   'feeling': 1,
#   'ever': 2},
#  'succeeded': {'in': 3},
#  'whenever': {'i': 1},
#  'maybe': {'the': 1},
#  'daisies': {'when': 1},
#  'tale': {'chapter': 1, 'perhaps': 1, 'said': 1, 'was': 1, 'they': 1},
#  'suet': {'yet': 1},
#  'so': {'and': 2,
#   'now': 1,
#   'managed': 1,
#   'often': 3,
#   'they': 8,
#   'suddenly': 2,
#   'indeed': 1,
#   'good': 1,
#   'it': 1,
#   'awfully': 1,
#   'as': 1,
#   'full': 1,
#   'eagerly': 1,
#   'desperate': 1,
#   'close': 2,
#   'useful': 1,
#   'quickly': 1,
#   'yet': 1,
#   'stingy': 1,
#   'after': 1,
#   'these': 1,
#   'said': 5,
#   'there': 1,
#   'when': 1,
#   'thinand': 1,
#   'long': 3,
#   'its': 1,
#   'ordered': 1,
#   'far': 3,
#   'much': 9,
#   'dreadfully': 1,
#   'violently': 1,
#   'you': 4,
#   'either': 1,
#   'used': 1,
#   'rich': 1,
#   'that': 7,
#   'very': 6,
#   'savage': 1,
#   'confused': 1,
#   'please': 1,
#   'mad': 1,
#   'closely': 1,
#   'on': 2,
#   'extremely': 1,
#   'grave': 2,
#   'he': 3,
#   'severely': 1,
#   'kind': 1,
#   'like': 1,
#   'nicely': 1,
#   'many': 4,
#   'ill': 1,
#   'proud': 1,
#   'alice': 7,
#   'large': 2,
#   'i': 2,
#   'outoftheway': 1,
#   'she': 29,
#   'shall': 1,
#   'easily': 2,
#   'small': 1,
#   'the': 1,
#   'bills': 1,
#   'shiny': 1},
#  'crept': {'a': 1},
#  'offend': {'the': 1},
#  'pulled': {'out': 1},
#  'talk': {'on': 1,
#   'about': 5,
#   'said': 2,
#   'i': 1,
#   'nonsense': 2,
#   'to': 1,
#   'at': 1,
#   'in': 1},
#  'recognised': {'the': 1},
#  'shoes': {'and': 1,
#   'on': 1,
#   'off': 1,
#   'done': 1,
#   'she': 1,
#   'under': 1,
#   'the': 1},
#  'seeing': {'the': 1},
#  'indeed': {'a': 1,
#   'and': 1,
#   'said': 7,
#   'cried': 1,
#   'tis': 1,
#   'to': 1,
#   'she': 2,
#   'were': 1,
#   'the': 1},
#  'pointed': {'to': 1},
#  'werent': {'to': 1},
#  'canary': {'called': 1},
#  'years': {'the': 1},
#  'course': {'yes': 1,
#   'what': 1,
#   'said': 1,
#   'just': 1,
#   'i': 1,
#   'of': 1,
#   'had': 1,
#   'it': 2,
#   'here': 1,
#   'alice': 1,
#   'twinkling': 1,
#   'to': 1,
#   'they': 1,
#   'not': 2,
#   'you': 3,
#   'was': 1,
#   'the': 3,
#   'he': 1},
#  'quarrelled': {'last': 1},
#  'shake': {'at': 1},
#  'argued': {'each': 1},
#  'cold': {'if': 1},
#  'still': {'and': 1,
#   'just': 1,
#   'sobbing': 1,
#   'it': 3,
#   'held': 1,
#   'running': 1,
#   'she': 1,
#   'in': 2,
#   'where': 1,
#   'as': 1},
#  'owl': {'and': 1, 'as': 1, 'had': 1},
#  'birds': {'and': 2,
#   'complained': 1,
#   'i': 1,
#   'hurried': 1,
#   'waiting': 1,
#   'with': 1,
#   'why': 1,
#   'tittered': 1},
#  'limbs': {'very': 1},
#  'yawning': {'and': 1, 'im': 1},
#  'thank': {'you': 3, 'ye': 1},
#  'curly': {'brown': 1},
#  'interesting': {'and': 1, 'dance': 1, 'is': 1, 'i': 1, 'story': 1},
#  'curls': {'got': 1},
#  'civil': {'of': 2, 'youd': 1},
#  'window': {'and': 3, 'i': 1, 'sure': 2, 'she': 1, 'that': 1},
#  'dreadfully': {'fond': 1, 'ugly': 1, 'savage': 1, 'one': 1, 'puzzled': 2},
#  'thump': {'down': 1, 'thump': 1},
#  'ours': {'they': 1},
#  'into': {'a': 15,
#   'little': 1,
#   'his': 2,
#   'her': 5,
#   'that': 3,
#   'this': 1,
#   'alarm': 1,
#   'it': 3,
#   'one': 1,
#   'hersshe': 1,
#   'alices': 3,
#   'hers': 1,
#   'the': 24,
#   'its': 5,
#   'custody': 1},
#  'happened': {'and': 1, 'how': 1, 'lately': 1, 'to': 2, 'so': 1, 'she': 1},
#  'roses': {'growing': 1, 'off': 1, 'five': 1},
#  'lonely': {'and': 1, 'on': 1},
#  'particularhere': {'bill': 1},
#  'tucked': {'away': 1, 'it': 1, 'her': 1},
#  'conversations': {'so': 1, 'in': 1},
#  'sooner': {'or': 1, 'than': 1},
#  'bound': {'into': 1},
#  'underneath': {'so': 1, 'her': 1},
#  'tails': {'fast': 1, 'in': 2},
#  'childlife': {'and': 1},
#  'half': {'high': 1,
#   'shut': 1,
#   'afraid': 1,
#   'hoping': 3,
#   'no': 1,
#   'of': 3,
#   'an': 2,
#   'down': 1,
#   'to': 3,
#   'expecting': 1,
#   'believed': 1,
#   'the': 1,
#   'my': 1,
#   'those': 1},
#  'not': {'growling': 1,
#   'pale': 1,
#   'would': 3,
#   'help': 2,
#   'cried': 1,
#   'be': 2,
#   'taste': 1,
#   'in': 2,
#   'notice': 1,
#   'marked': 1,
#   'an': 1,
#   'see': 1,
#   'attended': 1,
#   'im': 1,
#   'at': 5,
#   'choosing': 1,
#   'escape': 1,
#   'seem': 1,
#   'open': 1,
#   'yet': 2,
#   'as': 1,
#   'even': 2,
#   'stoop': 1,
#   'said': 6,
#   'appear': 1,
#   'for': 1,
#   'much': 3,
#   'make': 1,
#   'that': 2,
#   'long': 1,
#   'noticed': 1,
#   'looking': 1,
#   'to': 5,
#   'going': 1,
#   'easy': 1,
#   'ada': 1,
#   'answer': 2,
#   'got': 1,
#   'tell': 1,
#   'swim': 2,
#   'do': 1,
#   'we': 1,
#   'used': 1,
#   'gone': 3,
#   'venture': 2,
#   'get': 2,
#   'could': 5,
#   'becoming': 1,
#   'give': 1,
#   'sneeze': 1,
#   'here': 1,
#   'quite': 4,
#   'possibly': 1,
#   'have': 1,
#   'mad': 1,
#   'particular': 1,
#   'come': 1,
#   'dare': 2,
#   'remember': 3,
#   'a': 9,
#   'myself': 1,
#   'join': 3,
#   'like': 7,
#   'being': 1,
#   'attending': 1,
#   'i': 2,
#   'wish': 1,
#   'ill': 1,
#   'oh': 1,
#   'alice': 2,
#   'look': 1,
#   'feel': 1,
#   'so': 2,
#   'stand': 1,
#   'allow': 1,
#   'the': 6,
#   'feeling': 1,
#   'think': 2,
#   'talk': 1,
#   'otherwise': 1},
#  'now': {'and': 8,
#   'thatll': 1,
#   'im': 1,
#   'at': 1,
#   'in': 1,
#   'its': 1,
#   'if': 2,
#   'dears': 1,
#   'said': 1,
#   'for': 1,
#   'had': 1,
#   'hastily': 1,
#   'how': 1,
#   'only': 2,
#   'which': 1,
#   'you': 2,
#   'tell': 2,
#   'more': 1,
#   'chapter': 1,
#   'we': 1,
#   'run': 1,
#   'that': 1,
#   'what': 2,
#   'here': 1,
#   'five': 1,
#   'a': 1,
#   'about': 2,
#   'i': 5,
#   'ill': 1,
#   'dinah': 1,
#   'thought': 3,
#   'she': 2,
#   'let': 1,
#   'the': 3,
#   'my': 1},
#  'hall': {'and': 2,
#   'with': 1,
#   'after': 1,
#   'but': 2,
#   'which': 1,
#   'in': 1,
#   'was': 1},
#  'nor': {'did': 1, 'i': 1, 'less': 1},
#  'wont': {'thenbills': 1,
#   'be': 1,
#   'said': 1,
#   'do': 1,
#   'indeed': 1,
#   'walk': 1,
#   'thought': 1,
#   'she': 1,
#   'have': 1,
#   'interrupt': 1,
#   'you': 11,
#   'talk': 2,
#   'stand': 1},
#  'execute': {'the': 1},
#  'shouted': {'at': 1, 'the': 5, 'in': 1, 'alice': 1, 'out': 1},
#  'name': {'again': 1,
#   'like': 1,
#   'of': 2,
#   'is': 1,
#   'however': 1,
#   'signed': 1,
#   'alice': 1,
#   'w': 1,
#   'child': 1},
#  'chuckled': {'what': 1},
#  'corners': {'next': 1},
#  'drop': {'the': 1},
#  'jellyfish': {'out': 1},
#  'rock': {'and': 1},
#  'scolded': {'herself': 1},
#  'entirely': {'of': 1, 'disappeared': 1},
#  'creature': {'and': 1, 'down': 1, 'when': 1, 'but': 1},
#  'em': {'do': 1, 'up': 1, 'together': 1},
#  'bursting': {'out': 1},
#  'beloved': {'snail': 1},
#  'hurried': {'on': 1,
#   'off': 4,
#   'upstairs': 1,
#   'nervous': 1,
#   'back': 1,
#   'bythe': 1,
#   'tone': 1,
#   'out': 1},
#  'goose': {'who': 1, 'with': 1},
#  'skurried': {'away': 1},
#  'begun': {'to': 3, 'asking': 1, 'well': 1, 'my': 1, 'theyre': 1},
#  'year': {'it': 1, 'for': 1},
#  'happen': {'that': 1, 'next': 3, 'she': 1, 'in': 1, 'miss': 1, 'any': 1},
#  'worried': {'just': 1},
#  'giddy': {'and': 1, 'all': 1},
#  'living': {'at': 1, 'would': 1},
#  'canvas': {'bag': 1},
#  'opened': {'and': 1,
#   'his': 2,
#   'it': 2,
#   'their': 1,
#   'inwards': 1,
#   'the': 2,
#   'by': 1},
#  'concert': {'on': 1, 'given': 1},
#  'abide': {'figures': 1},
#  'hastily': {'replied': 2,
#   'and': 1,
#   'afraid': 1,
#   'for': 1,
#   'just': 1,
#   'i': 2,
#   'began': 1,
#   'interrupted': 1,
#   'but': 1,
#   'go': 1,
#   'said': 1,
#   'dried': 1,
#   'put': 1,
#   'consider': 1},
#  'looking': {'about': 1,
#   'hard': 1,
#   'for': 5,
#   'over': 2,
#   'anxiously': 3,
#   'up': 2,
#   'angrily': 1,
#   'down': 2,
#   'as': 1,
#   'at': 7,
#   'thoughtfully': 1,
#   'uneasily': 1,
#   'across': 1,
#   'round': 2},
#  'seriously': {'ill': 1},
#  'stupid': {'whether': 1, 'things': 2, 'and': 1, 'but': 1, 'for': 1},
#  'housemaid': {'she': 1},
#  'juror': {'it': 1},
#  'attended': {'to': 1},
#  'state': {'of': 1},
#  'mouthsand': {'theyre': 1},
#  'quite': {'follow': 1,
#   'right': 1,
#   'plainly': 1,
#   'tired': 2,
#   'unable': 1,
#   'as': 3,
#   'forgot': 2,
#   'impossible': 1,
#   'pale': 1,
#   'pleased': 2,
#   'out': 2,
#   'giddy': 1,
#   'silent': 2,
#   'jumped': 1,
#   'away': 1,
#   'faint': 1,
#   'unhappy': 1,
#   'strange': 1,
#   'slowly': 1,
#   'surprised': 1,
#   'dry': 1,
#   'sure': 1,
#   'relieved': 1,
#   'finished': 1,
#   'understand': 1,
#   'know': 1,
#   'dull': 1,
#   'a': 7,
#   'natural': 2,
#   'like': 1,
#   'crowded': 1,
#   'hungry': 1,
#   'forgetting': 3,
#   'enoughi': 1,
#   'so': 1,
#   'absurd': 1,
#   'forgotten': 1,
#   'makes': 1,
#   'agree': 1},
#  'bringing': {'these': 1, 'the': 1, 'herself': 1},
#  'soand': {'what': 1},
#  'besides': {'what': 1, 'thats': 1, 'shes': 1, 'all': 1},
#  'care': {'of': 2, 'where': 1, 'which': 1},
#  'advance': {'twice': 2, 'they': 1},
#  'beautify': {'is': 1},
#  'reasonable': {'pace': 1},
#  ...}

# %% [markdown]
# ## Q2(b) ii
# Conditional Probability

# %%
def getConditionalProbability(x, y, count=count, next_word_count = next_word_count):
    word = x
    nextWord = y
    
    if nextWord not in next_word_count[word]:
        return 0
    
    nextWordGivenWordCount = next_word_count[word][nextWord]
    nextWordAll = sum(next_word_count[word].values())
    return nextWordGivenWordCount/nextWordAll 

# Testing
getConditionalProbability('rabbit','just')
# Out:
# 0.022727272727272728

# %% [markdown]
# ## Q2(c) iii
#
# From Bayes' theorem
#
# $P(A \mid B)=\frac{P(B \mid A) \cdot P(A)}{P(B)}$
#
# $A, B =$ events
#
# $P(A \mid B) \quad =$ probability of A given B
#
# $P(B \mid A) \quad =$ probability of B given A
#
# $P(A), P(B) =$ the independent probabilities of A and B
#
# Here,
#
# A = nextWord
#
# B = word
#
#
# $P(nextWord \mid word)=\frac{P(word \mid nextWord) \cdot P(nextWord)}{P(word)}$

# %%
def predict(word, topk, count=count, next_word_count = next_word_count):

    possibleNextWords = next_word_count[word]
    ans = []
    pWord = getWordProbability(word)
    for nextWord in possibleNextWords.keys():        
        pNextWord = getWordProbability(nextWord)
        bayesEstimate =  getConditionalProbability(word, nextWord) * getWordProbability(nextWord)/ pWord
        ans.append((nextWord, bayesEstimate)) 
    topk = min(len(possibleNextWords), topk)
    return [(k,v) for k, v in sorted(ans, key=lambda item: item[1], reverse = True)][:topk]
#     return [(k) for k, v in sorted(ans, key=lambda item: item[1], reverse = True)][:topk]

print ("word most likely to follow 'a' is: " ,predict('a',1)[0])
print ("word most likely to follow 'the' is: " ,predict('the',1)[0])
print ("word most likely to follow 'splendidly' is: " ,predict('splendidly',1)[0])
print ("word most likely to follow 'exclaimed' is: " ,predict('exclaimed',1)[0])
# Out:
# word most likely to follow 'a' is:  ('little', 0.019377904182022114)
# word most likely to follow 'the' is:  ('queen', 0.001647382599763552)
# word most likely to follow 'splendidly' is:  ('dressed', 1.0)
# word most likely to follow 'exclaimed' is:  ('alice', 32.083333333333336)
